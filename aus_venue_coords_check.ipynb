# %%
import googlemaps
import pandas as pd
import re
import jellyfish
from itertools import combinations
from collections import Counter

# file to save suspicious venues
susp_ven_file = "suspicious_venues.txt"

aus_states_short2long = {"nsw": "new south wales", "vic": "victoria", "sa": "south australia", 
                         "tas": "tasmania", "qld": "queensland",
                  "wa": "western australia", "act": "australian capital territory", "nt": "northern territory"}
aus_cities = {"sydney", "melbourne", "perth", "adelaide", "brisbane", "canberra", "darwin", "hobart"}

aus_states_long2short = {v: k for k, v in aus_states_short2long.items()}

pois = ["airport", "park", "aquarium", "art gallery", "bakery", "bank", "bar", "store", "bowling alley", "cafe", "campground",
          "casino", "cemetery", "church", "city hall", "town hall", "courthouse", "embassy", "gym", "hospital", "library", "mosque", "island",
            "movie theater", "museum", "night club", "nightclub", "pharmacy", "police", "post office", "cinemas",
               "restaurant", "school", "shopping mall", "shopping centre", "spa", "stadium", "station", "synagogue", "university",
                   "zoo", "club", "casino", "theatre", "parklands", "hotel", "rsl", "oval", "showground", "racecourse", "gallery",
                   "resort", "square", "estate", "arena", "reserve", "winery", "wharf", "cathedral", "plaza", "opera house", "vineyard",
                   "farm", "aquatic centre", "pavillion", "convention centre", "community centre", "point", "institute", "business centre"]

street_types = """alley ally arcade arc avenue ave boulevard bvd bypass bypa circuit cct close cl corner crn court
                    ct crescent cres cul-de-sac cds drive dr esplanade esp green grn grove gr highway
                    hwy junction jnc lane lane link link mews mews parade pde place pl ridge rdge road rd 
                    square sq street st terrace tce""".split()

fake_venue_words = {"voucher", "tour", "vouchers", "tours", "testing"}

venues = pd.read_csv("aus_venues.txt", sep="\t")
print("venues to process: {}".format(len(venues)))

# make sure there are only single white spaces in names and addresses
for col in ["v_name", "v_addr"]:
    venues.loc[:,col] = venues.loc[:,col].str.replace("[.;-@_:#&()]"," ")
    venues.loc[:,col] = venues.loc[:,col].apply(lambda x: " ".join(str(x).strip().split()).lower())

# remove all numbers from addresses
venues.loc[:,"v_addr"] = venues.loc[:,"v_addr"].str.replace(r"\b\d+\b","")

# remove duplicates in names + addresses; some venues differ only in venue code
venues.drop_duplicates(subset=["v_name","v_addr"], inplace=True)
print("venues after removed duplicates: {}".format(len(venues)))

# first look for the outright suspicious venues
junk_venues = pd.concat([venues.loc[venues.v_addr.isnull() | venues.v_name.isnull(),:], 
                        venues.loc[venues.lat0.isnull() | venues.lng0.isnull(),:], 
                        venues.loc[(venues.v_name + ' ' + venues.v_addr).apply(lambda x: True if set(x.split()) & 
                                                                               fake_venue_words else False), :],
                        venues.loc[venues.v_addr.apply(lambda x: True if len(x.split()) < 2 else False), :]])
print("found {} junk venues".format(len(junk_venues)))
# remove these venues
venues = venues.loc[-venues.v_code.isin(junk_venues.v_code),:]
print("remaining venues: {}".format(len(venues)))
# Out:
# venues to process: 3027
# venues after removed duplicates: 2866
# found 118 junk venues
# remaining venues: 2756

# %%
# find venues with some POI in name
venues_poi_name = venues.loc[venues.v_name.apply(lambda x: True if [1 for c in range(3) 
                                                                    for w in combinations(x.split(), c) 
                                                                    if {" ".join(w)} & set(pois)] else False),:]
# add the search line column which for these venues is just their names
venues_poi_name["search_line"] = venues_poi_name["v_name"].str.replace(r"[-;.!$@_&]"," ")
print("venues with some POI in name: {}".format(len(venues_poi_name)))

# remove these venues
venues = venues.loc[-venues.v_code.isin(venues_poi_name.v_code),:]
print("venues left: {}".format(len(venues)))

# find venues with some POI in address
venues_poi_addr = venues.loc[venues.v_addr.apply(lambda x: True if [1 for c in range(3) 
                                                                    for w in combinations(x.split(), c) 
                                                                    if {" ".join(w)} & set(pois)] else False),:]
venues_poi_addr["search_line"] = venues_poi_addr["v_addr"].str.replace(r"[-;.!$@_&]"," ")
print("venues with some POI in address: {}".format(len(venues_poi_addr)))

# remove these venues
venues = venues.loc[-venues.v_code.isin(venues_poi_addr.v_code),:]
print("venues left: {}".format(len(venues)))
# Out:
# venues with some POI in name: 1513
# venues left: 1243
# venues with some POI in address: 184
# venues left: 1059
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
def find_states(st): 
    
    thestate = ""
    
    st_words = st.split()
    # one word states
    found_states = set(st_words) & set(aus_states_short2long.keys())
    
    if found_states:
        thestate = " ".join(found_states)
    else:
        for candidate_state in aus_states_long2short:
            res = re.search(r"\b({})\b".format(candidate_state), st)
            if res:
                thestate = aus_states_long2short[candidate_state]
    
    return thestate

# look at the addresses and find states
venues["state"] = venues["v_addr"].apply(find_states).str.upper()
print("found states for {} our of {} venues".format(sum(venues.state.notnull()), len(venues)))
# Out:
# found states for 1059 our of 1059 venues

# %%
subs_df = pd.read_csv("aus_subs_12APR2017.txt")
aus_suburbs = set(subs_df.loc[:,"sub"].tolist())

# %%
subu = []

for i, row in enumerate(venues.itertuples()):
    
    candidates = []
    
    # select only the part of suburb data frame related to this state
    s = set(subs_df.loc[subs_df.state == row.state,"sub"].tolist())
   
    oneword_suburbs = [sb for sb in s if len(sb.split()) == 1]
    #print("oneword suburbs: {}".format(len(oneword_suburbs)))
    
    st = str(row.v_addr).strip()
    
    for su in oneword_suburbs:
        if su in st.split():
            candidates.append(su)
    
    twoword_suburbs = [sb for sb in s if len(sb.split()) == 2]
    
    for su in twoword_suburbs:
        aw = st.split()
        if su in [w + " " + aw[i + 1] for i, w in enumerate(aw) if i + 1 < len(aw)]:
            candidates.append(su)
            
    threeword_suburbs = [sb for sb in s if len(sb.split()) == 2]
    for su in threeword_suburbs:
        aw = st.split()
        if su in [w + " " + aw[i + 1] + " " + aw[i + 2] for i, w in enumerate(aw) if i + 2 < len(aw)]:
            candidates.append(su)
    
    if len(candidates) > 1:
        #print("candidates=",candidates)
        for k in candidates:
            #print("st.split(k)=",st.split(k))
            if st.split(k):
                for part in st.split(k):
                    if set(part.split()) & set(street_types):
                        candidates = [k]
                    
    subu.append(",".join(candidates))
    
    
venues["suburb"] = subu

print("found suburbs for {} our of {} venues".format(sum(venues.suburb.notnull()), len(venues)))
# Out:
# candidates= ['perth', 'east perth']
# st.split(k)= ['fielder st east ', ' wa']
# st.split(k)= ['fielder st ', ' wa']
# candidates= ['ophir', 'bathurst']
# st.split(k)= ['', ' rd bathurst nsw']
# st.split(k)= ['ophir rd ', ' nsw']
# candidates= ['hindmarsh', 'adelaide']
# st.split(k)= ['', ' sq adelaide sa']
# st.split(k)= ['hindmarsh sq ', ' sa']
# candidates= ['melbourne', 'port melbourne']
# st.split(k)= ['ingles street port ', ' vic']
# st.split(k)= ['ingles street ', ' vic']
# candidates= ['southbank', 'melbourne']
# st.split(k)= ['sturt street ', ' melbourne vic']
# st.split(k)= ['sturt street southbank ', ' vic']
# candidates= ['annangrove', 'rouse hill']
# st.split(k)= ['- ', ' rd cnr edwards rd rouse hill nsw']
# st.split(k)= ['- annangrove rd cnr edwards rd ', ' nsw']
# candidates= ['penola', 'mount gambier']
# st.split(k)= ['', ' road mount gambier sa']
# st.split(k)= ['penola road ', ' sa']
# candidates= ['redfern', 'cleveland']
# st.split(k)= ['cleveland street ', ' nsw']
# st.split(k)= ['', ' street redfern nsw']
# candidates= ['adelaide', 'ebenezer']
# st.split(k)= ['1st floor ebenezer place corner rundle street ', ' sa']
# st.split(k)= ['1st floor ', ' place corner rundle street adelaide sa']
# candidates= ['kurrajong', 'singleton']
# st.split(k)= ['singleton rd ', ' east nsw']
# st.split(k)= ['', ' rd kurrajong east nsw']
# candidates= ['ulladulla', 'boree']
# st.split(k)= ['rowens arcade boree st ', ' nsw']
# st.split(k)= ['rowens arcade ', ' st ulladulla nsw']
# candidates= ['melbourne', 'st kilda']
# st.split(k)= ['anz pavilion 7th floor  st kilda road ', ' vic']
# st.split(k)= ['anz pavilion 7th floor  ', ' road melbourne vic']
# candidates= ['adelaide', 'mount barker']
# st.split(k)= ['', ' road mount barker sa']
# st.split(k)= ['adelaide road ', ' sa']
# candidates= ['leeuwin', 'augusta', 'margaret river']
# st.split(k)= ['', ' rd augusta margaret river wa']
# st.split(k)= ['leeuwin rd ', ' margaret river wa']
# st.split(k)= ['leeuwin rd augusta ', ' wa']
# candidates= ['tamworth', 'goonoo goonoo']
# st.split(k)= ['australian equine and livestock events centre aelec  goonoo goonoo road ', ' nsw']
# st.split(k)= ['australian equine and livestock events centre aelec  ', ' road tamworth nsw']
# candidates= ['lara', 'melbourne']
# st.split(k)= ['old melbourne rd ', ' vic']
# st.split(k)= ['old ', ' rd lara vic']
# candidates= ['wendouree', 'creswick']
# st.split(k)= ['cnr creswick rd howitt st ', ' vic']
# st.split(k)= ['cnr ', ' rd howitt st wendouree vic']
# candidates= ['sydney', 'the rocks']
# st.split(k)= ['pier / hickson road the rocks ', ' nsw']
# st.split(k)= ['pier / hickson road ', ' sydney nsw']
# candidates= ['neerabup', 'yanchep']
# st.split(k)= ['wattle ave off old yanchep road ', ' wa']
# st.split(k)= ['wattle ave off old ', ' road neerabup wa']
# candidates= ['oakleigh', 'huntingdale', 'oakleigh south']
# st.split(k)= ['huntingdale road ', ' south vic']
# st.split(k)= ['', ' road oakleigh south vic']
# st.split(k)= ['huntingdale road ', ' vic']
# candidates= ['perth', 'fremantle']
# st.split(k)= ['', ' fashion festival  mews road fremantle wa']
# st.split(k)= ['perth fashion festival  mews road ', ' wa']
# candidates= ['ewingsdale', 'byron bay']
# st.split(k)= ['', ' road byron bay nsw']
# st.split(k)= ['ewingsdale road ', ' nsw']
# candidates= ['nambour', 'woombye']
# st.split(k)= ['', ' connection road woombye qld']
# st.split(k)= ['nambour connection road ', ' qld']
# candidates= ['brisbane', 'south brisbane']
# st.split(k)= ['montague road south ', ' qld']
# st.split(k)= ['montague road ', ' qld']
# candidates= ['main beach', 'surfers paradise']
# st.split(k)= ['ground level shop - marina mirage seaworld drive ', ' surfers paradise qld']
# st.split(k)= ['ground level shop - marina mirage seaworld drive main beach ', ' qld']
# candidates= ['merewether', 'newcastle']
# st.split(k)= ['', ' st newcastle nsw']
# st.split(k)= ['merewether st ', ' nsw']
# candidates= ['sydney', 'bondi', 'bondi beach']
# st.split(k)= ['queen elizabeth drive off campbell parade bondi beach ', ' nsw']
# st.split(k)= ['queen elizabeth drive off campbell parade ', ' beach sydney nsw']
# st.split(k)= ['queen elizabeth drive off campbell parade ', ' sydney nsw']
# candidates= ['bordertown', 'naracoorte']
# st.split(k)= ['- naracoorte rd ', ' sa']
# st.split(k)= ['- ', ' rd bordertown sa']
# candidates= ['brighton', 'north brighton']
# st.split(k)= ['', ' road north ', ' sa']
# st.split(k)= ['brighton road ', ' sa']
# candidates= ['brisbane', 'boondall']
# st.split(k)= ['melaleuca drive boondall ', ' qld']
# st.split(k)= ['melaleuca drive ', ' brisbane qld']
# candidates= ['bowen', 'bowen hills']
# st.split(k)= ['gregory terrace ', ' hills qld qld']
# st.split(k)= ['gregory terrace ', ' qld qld']
# candidates= ['bunbury', 'boyanup', 'north boyanup']
# st.split(k)= ['north boyanup road ', ' wa']
# st.split(k)= ['north ', ' road bunbury wa']
# st.split(k)= ['', ' road bunbury wa']
# candidates= ['burnie', 'upper burnie']
# st.split(k)= ['upper ', ' tas']
# st.split(k)= ['', ' tas']
# candidates= ['brisbane', 'george street']
# st.split(k)= ['po box  george street ', ' qld']
# st.split(k)= ['po box  ', ' brisbane qld']
# candidates= ['beerburrum', 'caboolture']
# st.split(k)= ['cnr ', ' erskine streets caboolture qld']
# st.split(k)= ['cnr beerburrum erskine streets ', ' qld']
# candidates= ['beerburrum', 'caboolture']
# st.split(k)= ['', ' rd caboolture qld']
# st.split(k)= ['beerburrum rd ', ' qld']
# candidates= ['cairns', 'mulgrave']
# st.split(k)= ['cnr severin st mulgrave rd ', ' qld']
# st.split(k)= ['cnr severin st ', ' rd cairns qld']
# candidates= ['camden', 'oxley']
# st.split(k)= ['oxley street ', ' nsw']
# st.split(k)= ['', ' street camden nsw']
# candidates= ['parkes', 'canberra']
# st.split(k)= ['', ' place canberra act']
# st.split(k)= ['parkes place ', ' act']
# candidates= ['leeuwin', 'augusta']
# st.split(k)= ['', ' rd augusta western australia']
# st.split(k)= ['leeuwin rd ', ' western australia']
# candidates= ['beaconsfield', 'st kilda']
# st.split(k)= ['', ' pde st kilda west vic']
# st.split(k)= ['beaconsfield pde ', ' west vic']
# candidates= ['petrie', 'petrie terrace']
# st.split(k)= ['caxton street ', ' terrace qld']
# st.split(k)= ['caxton street ', ' qld']
# candidates= ['melbourne', 'prahran']
# st.split(k)= ['little chapel street prahran ', ' vic']
# st.split(k)= ['little chapel street ', ' melbourne vic']
# candidates= ['chatswood', 'sydney']
# st.split(k)= ['victoria avenue ', ' sydney nsw']
# st.split(k)= ['victoria avenue chatswood ', ' nsw']
# candidates= ['sydney', 'miller', 'north sydney']
# st.split(k)= ['suite  ground floor  miller st north ', ' nsw']
# st.split(k)= ['suite  ground floor  ', ' st north sydney nsw']
# st.split(k)= ['suite  ground floor  miller st ', ' nsw']
# candidates= ['sydney', 'albert']
# st.split(k)= ['jetty  albert st circular quay ', ' nsw']
# st.split(k)= ['jetty  ', ' st circular quay sydney nsw']
# candidates= ['ruse', 'rosehill']
# st.split(k)= ['unit   james ', ' drive cnr of grand ave north rosehill nsw']
# st.split(k)= ['unit   james ruse drive cnr of grand ave north ', ' nsw']
# candidates= ['putty', 'colo', 'colo heights']
# st.split(k)= ['', ' road colo heights nsw']
# st.split(k)= ['putty road ', ' heights nsw']
# st.split(k)= ['putty road ', ' nsw']
# candidates= ['osmington', 'margaret river']
# st.split(k)= ['', ' rd margaret river wa']
# st.split(k)= ['osmington rd ', ' wa']
# candidates= ['glenelg', 'glenelg north']
# st.split(k)= ['- adelphi terrace ', ' north sa']
# st.split(k)= ['- adelphi terrace ', ' sa']
# candidates= ['brisbane', 'george street']
# st.split(k)= ['george street ', ' qld']
# st.split(k)= ['', ' brisbane qld']
# candidates= ['mitchell', 'darwin']
# st.split(k)= ['', ' street darwin city nt']
# st.split(k)= ['mitchell street ', ' city nt']
# candidates= ['cronulla', 'sydney']
# st.split(k)= ['- ', ' street ', ' sydney nsw']
# st.split(k)= ['- cronulla street cronulla ', ' nsw']
# candidates= ['perth', 'burswood']
# st.split(k)= ['crown ', ' great eastern highway burswood wa']
# st.split(k)= ['crown perth great eastern highway ', ' wa']
# candidates= ['cleveland', 'surry hills']
# st.split(k)= ['level   ', ' st surry hills nsw']
# st.split(k)= ['level   cleveland st ', ' nsw']
# candidates= ['brisbane', 'george street']
# st.split(k)= ['george street ', ' qld']
# st.split(k)= ['', ' brisbane qld']
# candidates= ['conargo', 'deniliquin']
# st.split(k)= ['', ' road deniliquin nsw']
# st.split(k)= ['conargo road ', ' nsw']
# candidates= ['glenorchy', 'hobart']
# st.split(k)= ['brooker highway ', ' hobart tas']
# st.split(k)= ['brooker highway glenorchy ', ' tas']
# candidates= ['dandenong', 'dingley village']
# st.split(k)= ['cnr ', ' rd boundry rd dingley village vic']
# st.split(k)= ['cnr dandenong rd boundry rd ', ' vic']
# candidates= ['melbourne', 'flinders', 'flinders lane']
# st.split(k)= ['flinders lane ', ' vic']
# st.split(k)= ['', ' lane melbourne vic']
# st.split(k)= ['', ' melbourne vic']
# candidates= ['waters', 'sylvania', 'sylvania waters']
# st.split(k)= ['belgrave esplanade sylvania ', ' nsw']
# st.split(k)= ['belgrave esplanade ', ' waters nsw']
# st.split(k)= ['belgrave esplanade ', ' nsw']
# candidates= ['penrith', 'mulgoa']
# st.split(k)= ['', ' panthers mulgoa road ', ' nsw']
# st.split(k)= ['penrith panthers ', ' road penrith nsw']
# candidates= ['perth', 'hay']
# st.split(k)= ['hay street ', ' wa']
# st.split(k)= ['', ' street perth wa']
# candidates= ['dale', 'middle swan']
# st.split(k)= ['', ' road middle swan wa']
# st.split(k)= ['dale road ', ' wa']
# candidates= ['dunsborough', 'naturaliste']
# st.split(k)= ['naturaliste tce ', ' wa']
# st.split(k)= ['', ' tce dunsborough wa']
# candidates= ['hamilton', 'brisbane']
# st.split(k)= ['northside ', ' brisbane qld']
# st.split(k)= ['northside hamilton ', ' qld']
# candidates= ['brisbane', 'south brisbane']
# st.split(k)= ['st laurence’s college stephens road south ', ' qld']
# st.split(k)= ['st laurence’s college stephens road ', ' qld']
# candidates= ['warner', 'fortitude valley']
# st.split(k)= ['', ' street fortitude valley qld']
# st.split(k)= ['warner street ', ' qld']
# candidates= ['boonah', 'moogerah']
# st.split(k)= ['moogerah near ', ' qld']
# st.split(k)= ['', ' near boonah qld']
# candidates= ['wonglepong', 'canungra']
# st.split(k)= ['', ' road canungra qld']
# st.split(k)= ['wonglepong road ', ' qld']
# candidates= ['perth', 'fitzgerald']
# st.split(k)= ['- fitzgerald street ', ' wa']
# st.split(k)= ['- ', ' street perth wa']
# candidates= ['erina', 'erina fair']
# st.split(k)= ['the hive ', ' fair nsw']
# st.split(k)= ['the hive ', ' nsw']
# candidates= ['metricup', 'margaret river']
# st.split(k)= ['corner caves and ', ' roads margaret river wa']
# st.split(k)= ['corner caves and metricup roads ', ' wa']
# candidates= ['penrith', 'mulgoa']
# st.split(k)= ['mulgoa road ', ' nsw']
# st.split(k)= ['', ' road penrith nsw']
# candidates= ['melbourne', 'prahran']
# st.split(k)= ['commercial road prahran ', ' vic']
# st.split(k)= ['commercial road ', ' melbourne vic']
# candidates= ['melbourne', 'st kilda']
# st.split(k)= ['st kilda rd ', ' vic']
# st.split(k)= ['', ' rd melbourne vic']
# candidates= ['fairfield', 'smithfield']
# st.split(k)= ['smithfield road ', ' nsw']
# st.split(k)= ['', ' road fairfield nsw']
# candidates= ['wendouree', 'ballarat']
# st.split(k)= ['', ' pde ballarat vic']
# st.split(k)= ['wendouree pde ', ' vic']
# candidates= ['melbourne', 'wodonga']
# st.split(k)= ['', ' road wodonga vic']
# st.split(k)= ['melbourne road ', ' vic']
# candidates= ['melbourne', 'west melbourne']
# st.split(k)= ['dudley street west ', ' vic']
# st.split(k)= ['dudley street ', ' vic']
# candidates= ['adelaide', 'north adelaide']
# st.split(k)= ['ward street north ', ' sa']
# st.split(k)= ['ward street ', ' sa']
# candidates= ['newcastle', 'newcastle east']
# st.split(k)= ['nobbys road ', ' east nsw']
# st.split(k)= ['nobbys road ', ' nsw']
# candidates= ['melbourne', 'flinders']
# st.split(k)= ['flinders st ', ' vic']
# st.split(k)= ['', ' st melbourne vic']
# candidates= ['breakwater', 'geelong', 'east geelong']
# st.split(k)= ['', ' rd east geelong vic']
# st.split(k)= ['breakwater rd east ', ' vic']
# st.split(k)= ['breakwater rd ', ' vic']
# candidates= ['breakwater', 'geelong', 'east geelong']
# st.split(k)= ['', ' road east geelong vic']
# st.split(k)= ['breakwater road east ', ' vic']
# st.split(k)= ['breakwater road ', ' vic']
# candidates= ['redfern', 'cleveland']
# st.split(k)= ['cleveland st ', ' nsw']
# st.split(k)= ['', ' st redfern nsw']
# candidates= ['clarence', 'port macquarie']
# st.split(k)= ['', ' street port macquarie nsw']
# st.split(k)= ['clarence street ', ' nsw']
# candidates= ['rockhampton', 'yaamba']
# st.split(k)= ['yaamba st nth ', ' qld']
# st.split(k)= ['', ' st nth rockhampton qld']
# candidates= ['ainslie', 'braddon']
# st.split(k)= ['', ' avenue braddon act']
# st.split(k)= ['ainslie avenue ', ' act']
# candidates= ['mitchell', 'canberra']
# st.split(k)= ['flemington road ', ' canberra act']
# st.split(k)= ['flemington road mitchell ', ' act']
# candidates= ['melbourne', 'st kilda']
# st.split(k)= ['st kilda road ', ' vic']
# st.split(k)= ['', ' road melbourne vic']
# candidates= ['adelaide', 'port adelaide']
# st.split(k)= ['st vincent st port ', ' sa sa']
# st.split(k)= ['st vincent st ', ' sa sa']
# candidates= ['healesville', 'badger creek']
# st.split(k)= ['badger creek road ', ' vic']
# st.split(k)= ['', ' road healesville vic']
# candidates= ['merewether', 'newcastle']
# st.split(k)= ['', ' street newcastle nsw']
# st.split(k)= ['merewether street ', ' nsw']
# candidates= ['pokolbin', 'broke']
# st.split(k)= ['corner of broke rd mcdonalds rd ', ' nsw']
# st.split(k)= ['corner of ', ' rd mcdonalds rd pokolbin nsw']
# candidates= ['melbourne', 'brunswick', 'fitzroy']
# st.split(k)= ['brunswick street fitzroy ', ' vic']
# st.split(k)= ['', ' street fitzroy melbourne vic']
# st.split(k)= ['brunswick street ', ' melbourne vic']
# candidates= ['boondall', 'sandgate']
# st.split(k)= ['sandgate road ', ' qld']
# st.split(k)= ['', ' road boondall qld']
# candidates= ['mountain', 'jamberoo', 'knights hill']
# st.split(k)= ['jamberoo ', ' rd knights hill nsw']
# st.split(k)= ['', ' mountain rd knights hill nsw']
# st.split(k)= ['jamberoo mountain rd ', ' nsw']
# candidates= ['ingham', 'lannercost']
# st.split(k)= ['lannercost st ', ' qld']
# st.split(k)= ['', ' st ingham qld']
# candidates= ['ipswich', 'limestone']
# st.split(k)= ['limestone nicholas streets ', ' qld']
# st.split(k)= ['', ' nicholas streets ipswich qld']
# candidates= ['belrose', 'niangala']
# st.split(k)= ['unit   niangala close opposite the supa centre ', ' nsw']
# st.split(k)= ['unit   ', ' close opposite the supa centre belrose nsw']
# candidates= ['southbank', 'melbourne']
# st.split(k)= ['abc ', ' centre  ', ' blvd cnr ', ' blvd sturt streets melbourne vic']
# st.split(k)= ['abc southbank centre  southbank blvd cnr southbank blvd sturt streets ', ' vic']
# candidates= ['melbourne', 'sutton', 'north melbourne']
# st.split(k)= ['sutton street north ', ' vic']
# st.split(k)= ['', ' street north melbourne vic']
# st.split(k)= ['sutton street ', ' vic']
# candidates= ['balgowlah', 'north balgowlah']
# st.split(k)= ['north ', ' northern beaches and blue mountains nsw']
# st.split(k)= ['', ' northern beaches and blue mountains nsw']
# candidates= ['penrith', 'mulgoa']
# st.split(k)= ['mulgoa road ', ' nsw']
# st.split(k)= ['', ' road penrith nsw']
# candidates= ['kennedy', 'kilcoy']
# st.split(k)= ['mcauley ', ' streets kilcoy qld']
# st.split(k)= ['mcauley kennedy streets ', ' qld']
# candidates= ['brisbane', 'kingston']
# st.split(k)= ['jacaranda avenue kingston ', ' qld']
# st.split(k)= ['jacaranda avenue ', ' brisbane qld']
# candidates= ['belford', 'lower belford']
# st.split(k)= ['kirkton road hunter valley region lower ', ' nsw']
# st.split(k)= ['kirkton road hunter valley region ', ' nsw']
# candidates= ['boorga', 'griffith']
# st.split(k)= ['', ' rd griffith nsw']
# st.split(k)= ['boorga rd ', ' nsw']
# candidates= ['adelaide', 'goodwood']
# st.split(k)= ['89e goodwood road goodwood ', ' sa']
# st.split(k)= ['89e ', ' road ', ' adelaide sa']
# candidates= ['carlton', 'cardigan']
# st.split(k)= ['cardigan street ', ' vic']
# st.split(k)= ['', ' street carlton vic']
# candidates= ['brisbane', 'fortitude valley']
# st.split(k)= ['light street fortitude valley ', ' qld']
# st.split(k)= ['light street ', ' brisbane qld']
# candidates= ['crestmead', 'browns plains']
# st.split(k)= ['- browns plains road ', ' qld']
# st.split(k)= ['- ', ' road crestmead qld']
# candidates= ['joondalup', 'somerville']
# st.split(k)= ['somerville uwa or ', ' pines ecu wa']
# st.split(k)= ['', ' uwa or joondalup pines ecu wa']
# candidates= ['malvern', 'south yarra']
# st.split(k)= ['cnr of little chapel street ', ' road south yarra vic']
# st.split(k)= ['cnr of little chapel street malvern road ', ' vic']
# candidates= ['mackay', 'milton']
# st.split(k)= ['milton street ', ' qld']
# st.split(k)= ['', ' street mackay qld']
# candidates= ['mackay', 'north mackay']
# st.split(k)= ['off norris road north ', ' qld']
# st.split(k)= ['off norris road ', ' qld']
# candidates= ['federal', 'lake george']
# st.split(k)= ['westering ', ' hwy lake george nsw']
# st.split(k)= ['westering federal hwy ', ' nsw']
# candidates= ['kuluin', 'maroochydore']
# st.split(k)= ['maroochydore road ', ' qld']
# st.split(k)= ['', ' road kuluin qld']
# candidates= ['sydney', 'north sydney']
# st.split(k)= ['- mount street north ', ' nsw']
# st.split(k)= ['- mount street ', ' nsw']
# candidates= ['melbourne', 'blackwood', 'north melbourne']
# st.split(k)= ['blackwood street north ', ' vic']
# st.split(k)= ['', ' street north melbourne vic']
# st.split(k)= ['blackwood street ', ' vic']
# candidates= ['ascot', 'epsom', 'ascot vale']
# st.split(k)= ['epsom road ', ' vale vic']
# st.split(k)= ['', ' road ascot vale vic']
# st.split(k)= ['epsom road ', ' vic']
# candidates= ['docklands', 'melbourne']
# st.split(k)= ['waterfront way ', ' melbourne vic']
# st.split(k)= ['waterfront way docklands ', ' vic']
# candidates= ['adelaide', 'north adelaide']
# st.split(k)= ['war memorial drive north ', ' sa']
# st.split(k)= ['war memorial drive ', ' sa']
# candidates= ['mitchell', 'kandanga', 'upper kandanga']
# st.split(k)= ['lot  ', ' creek road upper kandanga mary valley noosa hinterland qld']
# st.split(k)= ['lot  mitchell creek road upper ', ' mary valley noosa hinterland qld']
# st.split(k)= ['lot  mitchell creek road ', ' mary valley noosa hinterland qld']
# candidates= ['brisbane', 'east brisbane']
# st.split(k)= ['oaklands parade east ', ' qld']
# st.split(k)= ['oaklands parade ', ' qld']
# candidates= ['bathurst', 'mount panorama']
# st.split(k)= ['mount panorama ', ' nsw']
# st.split(k)= ['', ' bathurst nsw']
# candidates= ['laidley', 'mulgowie']
# st.split(k)= ['', ' mulgowie road mulgowie qld']
# st.split(k)= ['laidley ', ' road ', ' qld']
# candidates= ['mutdapilly', 'coleyville']
# st.split(k)= ['- coleyville road ', ' qld']
# st.split(k)= ['- ', ' road mutdapilly qld']
# candidates= ['sydney', 'kensington']
# st.split(k)= ['anzac parade kensington ', ' nsw']
# st.split(k)= ['anzac parade ', ' sydney nsw']
# candidates= ['nashdale', 'cargo', 'orange']
# st.split(k)= ['cargo road ', ' orange nsw']
# st.split(k)= ['', ' road nashdale orange nsw']
# st.split(k)= ['cargo road nashdale ', ' nsw']
# candidates= ['hackney', 'adelaide']
# st.split(k)= ['', ' road adelaide sa']
# st.split(k)= ['hackney road ', ' sa']
# candidates= ['veresdale', 'veresdale scrub']
# st.split(k)= ['', ' scrub rd ', ' scrub qld']
# st.split(k)= ['', ' rd ', ' qld']
# candidates= ['southport', 'nerang']
# st.split(k)= ['', ' road nerang qld']
# st.split(k)= ['southport road ', ' qld']
# candidates= ['melbourne', 'parkville']
# st.split(k)= ['uni of ', '  swanston st parkville vic']
# st.split(k)= ['uni of melbourne  swanston st ', ' vic']
# candidates= ['newcastle', 'newcastle west']
# st.split(k)= ['king st union st ', ' west nsw']
# st.split(k)= ['king st union st ', ' nsw']
# candidates= ['newcastle', 'newcastle west']
# st.split(k)= ['corner of parry and union streets ', ' west nsw']
# st.split(k)= ['corner of parry and union streets ', ' nsw']
# candidates= ['shortland', 'newcastle']
# st.split(k)= ['corner of ', ' esplanade and zaara street newcastle nsw']
# st.split(k)= ['corner of shortland esplanade and zaara street ', ' nsw']
# candidates= ['perth', 'fremantle']
# st.split(k)= ['south terrace fremantle ', ' wa']
# st.split(k)= ['south terrace ', ' perth wa']
# candidates= ['wendouree', 'ballarat']
# st.split(k)= ['ballarat botanical gardens ', ' parade ballarat vic']
# st.split(k)= ['', ' botanical gardens wendouree parade ', ' vic']
# candidates= ['oxley', 'crows nest']
# st.split(k)= ['', ' st crows nest nsw']
# st.split(k)= ['oxley st ', ' nsw']
# candidates= ['newtown', 'enmore']
# st.split(k)= ['- enmore road ', ' nsw']
# st.split(k)= ['- ', ' road newtown nsw']
# candidates= ['newington', 'stanmore']
# st.split(k)= ['', ' college  stanmore road stanmore nsw']
# st.split(k)= ['newington college  ', ' road ', ' nsw']
# candidates= ['errowanbang', 'carcoar']
# st.split(k)= ['lot  ', ' road carcoar nsw']
# st.split(k)= ['lot  errowanbang road ', ' nsw']
# candidates= ['orange', 'march']
# st.split(k)= ['cnr march and peisley street ', ' nsw']
# st.split(k)= ['cnr ', ' and peisley street orange nsw']
# candidates= ['arnold', 'orbost']
# st.split(k)= ['', ' street orbost vic']
# st.split(k)= ['arnold street ', ' vic']
# candidates= ['argyle', 'the rocks']
# st.split(k)= ['circular quay west entry via cnr george ', ' st the rocks nsw']
# st.split(k)= ['circular quay west entry via cnr george argyle st ', ' nsw']
# candidates= ['caboolture', 'donnybrook']
# st.split(k)= ['quinn road near ', ' donnybrook qld']
# st.split(k)= ['quinn road near caboolture ', ' qld']
# candidates= ['gnangara', 'henley brook']
# st.split(k)= ['swan valley ', ' road near the corner of west henley brook wa']
# st.split(k)= ['swan valley gnangara road near the corner of west ', ' wa']
# candidates= ['perth', 'south perth']
# st.split(k)= ['south ', ' esplanade south ', ' wa']
# st.split(k)= ['', ' esplanade ', ' wa']
# candidates= ['hepburn', 'hepburn springs']
# st.split(k)= ['main road ', ' springs vic']
# st.split(k)= ['main road ', ' vic']
# candidates= ['sydney', 'bathurst']
# st.split(k)= ['piper street bathurst ', ' nsw']
# st.split(k)= ['piper street ', ' sydney nsw']
# candidates= ['penrith', 'mulgoa']
# st.split(k)= ['cnr mulgoa road ramsey street ', ' nsw']
# st.split(k)= ['cnr ', ' road ramsey street penrith nsw']
# candidates= ['crawley', 'stirling']
# st.split(k)= ['uwa  stirling highway ', ' wa']
# st.split(k)= ['uwa  ', ' highway crawley wa']
# candidates= ['perth', 'burswood']
# st.split(k)= ['poolside crown metropol ', ' great eastern highway burswood wa']
# st.split(k)= ['poolside crown metropol perth great eastern highway ', ' wa']
# candidates= ['sydney', 'alexandria']
# st.split(k)= ['gardeners road alexandria ', ' nsw']
# st.split(k)= ['gardeners road ', ' sydney nsw']
# candidates= ['mowbray', 'douglas', 'port douglas']
# st.split(k)= ['', ' street port douglas qld']
# st.split(k)= ['mowbray street port ', ' qld']
# st.split(k)= ['mowbray street ', ' qld']
# candidates= ['fitzroy', 'st kilda']
# st.split(k)= ['', ' street st kilda vic']
# st.split(k)= ['fitzroy street ', ' vic']
# candidates= ['melbourne', 'west melbourne']
# st.split(k)= ['adderley street west ', ' vic']
# st.split(k)= ['adderley street ', ' vic']
# candidates= ['talbot', 'burnbank', 'lexton']
# st.split(k)= ['lexton ', ' rd burnbank vic']
# st.split(k)= ['lexton talbot rd ', ' vic']
# st.split(k)= ['', ' talbot rd burnbank vic']
# candidates= ['queanbeyan', 'glebe']
# st.split(k)= ['glebe avenue ', ' nsw']
# st.split(k)= ['', ' avenue queanbeyan nsw']
# candidates= ['hesse', 'queenscliff']
# st.split(k)= ['cnr symonds ', ' st queenscliff vic']
# st.split(k)= ['cnr symonds hesse st ', ' vic']
# candidates= ['beerburrum', 'caboolture']
# st.split(k)= ['cnr tuckeroo drive and ', ' road caboolture qld']
# st.split(k)= ['cnr tuckeroo drive and beerburrum road ', ' qld']
# candidates= ['douglas', 'port douglas']
# st.split(k)= ['marina mirage port ', ' queensland qld']
# st.split(k)= ['marina mirage ', ' queensland qld']
# candidates= ['geographe', 'dunsborough', 'quindalup']
# st.split(k)= ['', ' bay road quindalup opposite mcdermott street dunsborough wa']
# st.split(k)= ['geographe bay road quindalup opposite mcdermott street ', ' wa']
# st.split(k)= ['geographe bay road ', ' opposite mcdermott street dunsborough wa']
# candidates= ['amberley', 'ipswich']
# st.split(k)= ['raaf base ', ' south ', ' road ipswich qld']
# st.split(k)= ['raaf base amberley south amberley road ', ' qld']
# candidates= ['bathurst', 'mount panorama', 'sunny corner']
# st.split(k)= ['sunny corner forest / mount panorama ', ' nsw']
# st.split(k)= ['sunny corner forest / ', ' bathurst nsw']
# st.split(k)= ['', ' forest / mount panorama bathurst nsw']
# candidates= ['randwick', 'st pauls']
# st.split(k)= ['st pauls st ', ' nsw']
# st.split(k)= ['', ' st randwick nsw']
# candidates= ['toodyay', 'red hill']
# st.split(k)= ['lot  ', ' rd red hill wa']
# st.split(k)= ['lot  toodyay rd ', ' wa']
# candidates= ['perth', 'north perth']
# st.split(k)= ['vincent street north ', ' wa']
# st.split(k)= ['vincent street ', ' wa']
# candidates= ['redgate', 'margaret river']
# st.split(k)= ['', ' beach margaret river wa']
# st.split(k)= ['redgate beach ', ' wa']
# candidates= ['subiaco', 'hay']
# st.split(k)= ['hay street ', ' wa']
# st.split(k)= ['', ' street subiaco wa']
# candidates= ['subiaco', 'hay']
# st.split(k)= ['hay street ', ' wa']
# st.split(k)= ['', ' street subiaco wa']
# candidates= ['bowen', 'bowen hills']
# st.split(k)= ['gregory terrace ', ' hills qld']
# st.split(k)= ['gregory terrace ', ' qld']
# candidates= ['bowen', 'bowen hills']
# st.split(k)= ['', ' hills qld']
# st.split(k)= ['', ' qld']
# candidates= ['rockhampton', 'yaamba']
# st.split(k)= ['yaamba rd ', ' qld']
# st.split(k)= ['', ' rd rockhampton qld']
# candidates= ['rockhampton', 'wandal']
# st.split(k)= ['exhibition road wandal ', ' qld']
# st.split(k)= ['exhibition road ', ' rockhampton qld']
# candidates= ['crawley', 'stirling']
# st.split(k)= ['uwa  stirling highway ', ' wa']
# st.split(k)= ['uwa  ', ' highway crawley wa']
# candidates= ['nicholson', 'carlton']
# st.split(k)= ['', ' street carlton vic']
# st.split(k)= ['nicholson street ', ' vic']
# candidates= ['ascot', 'epsom', 'ascot vale']
# st.split(k)= ['epsom rd ', ' vale vic']
# st.split(k)= ['', ' rd ascot vale vic']
# st.split(k)= ['epsom rd ', ' vic']
# candidates= ['ascot', 'epsom', 'ascot vale']
# st.split(k)= ['epsom road ', ' vale vic']
# st.split(k)= ['', ' road ascot vale vic']
# st.split(k)= ['epsom road ', ' vic']
# candidates= ['alison', 'randwick']
# st.split(k)= ['', ' road randwick nsw']
# st.split(k)= ['alison road ', ' nsw']
# candidates= ['burwood', 'belgrave']
# st.split(k)= ['', ' highway weirdsville belgrave vic']
# st.split(k)= ['burwood highway weirdsville ', ' vic']
# candidates= ['maffra', 'sale']
# st.split(k)= ['', ' road sale vic']
# st.split(k)= ['maffra road ', ' vic']
# candidates= ['fremantle', 'north fremantle']
# st.split(k)= ['port beach road north ', ' wa']
# st.split(k)= ['port beach road ', ' wa']
# candidates= ['metricup', 'wilyabrup']
# st.split(k)= ['', ' road wilyabrup wa']
# st.split(k)= ['metricup road ', ' wa']
# candidates= ['caversham', 'west swan']
# st.split(k)= ['west swan road ', ' wa']
# st.split(k)= ['', ' road caversham wa']
# candidates= ['newcastle', 'cooks hill']
# st.split(k)= ['', ' grammar corner of union parkway avenue cooks hill nsw']
# st.split(k)= ['newcastle grammar corner of union parkway avenue ', ' nsw']
# candidates= ['saumarez', 'armidale']
# st.split(k)= ['', ' rd armidale nsw']
# st.split(k)= ['saumarez rd ', ' nsw']
# candidates= ['perth', 'west perth']
# st.split(k)= ['sutherland street west ', ' wa']
# st.split(k)= ['sutherland street ', ' wa']
# candidates= ['adelaide', 'sellicks beach']
# st.split(k)= ['sellicks beach ', ' sa']
# st.split(k)= ['', ' adelaide sa']
# candidates= ['deniliquin', 'moama']
# st.split(k)= ['old ', ' rd moama nsw']
# st.split(k)= ['old deniliquin rd ', ' nsw']
# candidates= ['moyston', 'great western']
# st.split(k)= ['', ' road great western vic']
# st.split(k)= ['moyston road ', ' vic']
# candidates= ['chippendale', 'cleveland']
# st.split(k)= ['corner city road and cleveland street ', ' nsw']
# st.split(k)= ['corner city road and ', ' street chippendale nsw']
# candidates= ['hamilton', 'shepparton']
# st.split(k)= ['', ' st shepparton vic']
# st.split(k)= ['hamilton st ', ' vic']
# candidates= ['brisbane', 'toogoolawah']
# st.split(k)= ['ramblers parachute centre  ', ' valley highway toogoolawah qld']
# st.split(k)= ['ramblers parachute centre  brisbane valley highway ', ' qld']
# candidates= ['clifford', 'surfers paradise']
# st.split(k)= ['cnr surfers paradise boulevard ', ' st surfers paradise qld']
# st.split(k)= ['cnr ', ' boulevard clifford st ', ' qld']
# candidates= ['cairns', 'smithfield']
# st.split(k)= ['cnr captian cook hwy ', ' western arterial road smithfield qld']
# st.split(k)= ['cnr captian cook hwy cairns western arterial road ', ' qld']
# candidates= ['chippendale', 'cleveland']
# st.split(k)= ['corner of city road and cleveland street ', ' nsw']
# st.split(k)= ['corner of city road and ', ' street chippendale nsw']
# candidates= ['sydney', 'liverpool']
# st.split(k)= ['level   liverpool street ', ' nsw']
# st.split(k)= ['level   ', ' street sydney nsw']
# candidates= ['kensington', 'leabrook']
# st.split(k)= ['', ' road leabrook sa']
# st.split(k)= ['kensington road ', ' sa']
# candidates= ['melbourne', 'batman']
# st.split(k)= ['batman ave ', ' vic']
# st.split(k)= ['', ' ave melbourne vic']
# candidates= ['springfield', 'camira']
# st.split(k)= ['cnr ', ' pky commerical drive camira qld']
# st.split(k)= ['cnr springfield pky commerical drive ', ' qld']
# candidates= ['melbourne', 'west melbourne']
# st.split(k)= ['cnr howard victoria streets west ', ' vic']
# st.split(k)= ['cnr howard victoria streets ', ' vic']
# candidates= ['hobart', 'north hobart']
# st.split(k)= ['elizabeth street north ', ' tas']
# st.split(k)= ['elizabeth street ', ' tas']
# candidates= ['fullerton', 'stockton']
# st.split(k)= ['', ' road stockton nsw']
# st.split(k)= ['fullerton road ', ' nsw']
# candidates= ['subiaco', 'hamersley']
# st.split(k)= ['hamersley road ', ' wa']
# st.split(k)= ['', ' road subiaco wa']
# candidates= ['subiaco', 'hamersley']
# st.split(k)= ['hamersley rd ', ' wa']
# st.split(k)= ['', ' rd subiaco wa']
# candidates= ['subiaco', 'hamersley']
# st.split(k)= ['hamersley road ', ' wa']
# st.split(k)= ['', ' road subiaco wa']
# candidates= ['sunbury', 'macedon']
# st.split(k)= ['macedon st ', ' vic']
# st.split(k)= ['', ' st sunbury vic']
# candidates= ['leslie', 'townsville']
# st.split(k)= ['bearakwater terminal sir ', ' thiess drive townsville qld']
# st.split(k)= ['bearakwater terminal sir leslie thiess drive ', ' qld']
# candidates= ['crawley', 'stirling']
# st.split(k)= ['uwa  stirling highway ', ' wa']
# st.split(k)= ['uwa  ', ' highway crawley wa']
# candidates= ['coomera', 'upper coomera']
# st.split(k)= ['bambi close upper ', ' qld']
# st.split(k)= ['bambi close ', ' qld']
# candidates= ['fremantle', 'north fremantle']
# st.split(k)= ['queen victoria street north ', ' wa']
# st.split(k)= ['queen victoria street ', ' wa']
# candidates= ['penrith', 'castlereagh']
# st.split(k)= ['castlereagh road ', ' nsw']
# st.split(k)= ['', ' road penrith nsw']
# candidates= ['tamworth', 'goonoo goonoo']
# st.split(k)= ['goonoo goonoo road ', ' nsw']
# st.split(k)= ['', ' road tamworth nsw']
# candidates= ['launceston', 'longford']
# st.split(k)= ['goldrush ballooning longford south-west of ', ' tas']
# st.split(k)= ['goldrush ballooning ', ' south-west of launceston tas']
# candidates= ['waterloo', 'surry hills']
# st.split(k)= ["the reader's digest building  ", ' street surry hills nsw']
# st.split(k)= ["the reader's digest building  waterloo street ", ' nsw']
# candidates= ['fullarton', 'glen osmond']
# st.split(k)= ['glen osmond rd ', ' sa']
# st.split(k)= ['', ' rd fullarton sa']
# candidates= ['bundall', 'surfers paradise']
# st.split(k)= ['', ' road surfers paradise qld']
# st.split(k)= ['bundall road ', ' qld']
# candidates= ['melbourne', 'st kilda']
# st.split(k)= ['st kilda rd ', ' vic']
# st.split(k)= ['', ' rd melbourne vic']
# candidates= ['darlinghurst', 'kings cross']
# st.split(k)= ['', ' rd kings cross nsw']
# st.split(k)= ['darlinghurst rd ', ' nsw']
# candidates= ['melbourne', 'north melbourne']
# st.split(k)= ['errol street north ', ' vic']
# st.split(k)= ['errol street ', ' vic']
# candidates= ['camden', 'campbelltown']
# st.split(k)= ['- ', ' rd campbelltown nsw']
# st.split(k)= ['- camden rd ', ' nsw']
# candidates= ['perth', 'burswood']
# st.split(k)= ['crown ', ' great eastern highway burswood wa']
# st.split(k)= ['crown perth great eastern highway ', ' wa']
# candidates= ['brisbane', 'woolloongabba']
# st.split(k)= ['', ' cricket ground vulture street woolloongabba qld']
# st.split(k)= ['brisbane cricket ground vulture street ', ' qld']
# candidates= ['perth', 'joondalup']
# st.split(k)= ['grand blvd joondalup ', ' wa']
# st.split(k)= ['grand blvd ', ' perth wa']
# candidates= ['brisbane', 'west end']
# st.split(k)= ['boundary street west end ', ' qld']
# st.split(k)= ['boundary street ', ' brisbane qld']
# candidates= ['carrington', 'castle hill']
# st.split(k)= ['', ' road castle hill nsw']
# st.split(k)= ['carrington road ', ' nsw']
# candidates= ['windsor', 'rouse hill']
# st.split(k)= ['lot / ', ' rd rouse hill nsw']
# st.split(k)= ['lot / windsor rd ', ' nsw']
# candidates= ['warner', 'fortitude valley']
# st.split(k)= ['', ' street fortitude valley qld']
# st.split(k)= ['warner street ', ' qld']
# candidates= ['southbank', 'melbourne']
# st.split(k)= ['level  crown entertainment complex whiteman st ', ' melbourne vic']
# st.split(k)= ['level  crown entertainment complex whiteman st southbank ', ' vic']
# candidates= ['brisbane', 'bowen', 'bowen hills']
# st.split(k)= ['gregory terrace bowen hills ', ' qld']
# st.split(k)= ['gregory terrace ', ' hills brisbane qld']
# st.split(k)= ['gregory terrace ', ' brisbane qld']
# candidates= ['hobart', 'sandy bay']
# st.split(k)= ['sandy bay road ', ' tas']
# st.split(k)= ['', ' road hobart tas']
# candidates= ['darlinghurst', 'bourke']
# st.split(k)= ['level / bourke st ', ' nsw']
# st.split(k)= ['level / ', ' st darlinghurst nsw']
# candidates= ['melbourne', 'flinders', 'flinders lane']
# st.split(k)= ['flinders lane ', ' vic']
# st.split(k)= ['', ' lane melbourne vic']
# st.split(k)= ['', ' melbourne vic']
# candidates= ['sydney', 'newtown']
# st.split(k)= ['king street newtown ', ' nsw']
# st.split(k)= ['king street ', ' sydney nsw']
# candidates= ['southbank', 'clarendon']
# st.split(k)= ['corner of clarendon street and crown riverwalk crown entertainment complex ', ' vic']
# st.split(k)= ['corner of ', ' street and crown riverwalk crown entertainment complex southbank vic']
# candidates= ['melbourne', 'brunswick']
# st.split(k)= ['leslie street brunswick ', ' victoria']
# st.split(k)= ['leslie street ', ' melbourne victoria']
# candidates= ['nelson', 'nelson bay']
# st.split(k)= ['', ' bay road ', ' bay nsw']
# st.split(k)= ['', ' road ', ' nsw']
# candidates= ['glenlyon', 'gladstone']
# st.split(k)= ['', ' rd gladstone qld']
# st.split(k)= ['glenlyon rd ', ' qld']
# candidates= ['glenvale', 'toowoomba']
# st.split(k)= ['', ' rd toowoomba qld']
# st.split(k)= ['glenvale rd ', ' qld']
# candidates= ['pokolbin', 'broke']
# st.split(k)= ['broke road ', ' nsw']
# st.split(k)= ['', ' road pokolbin nsw']
# candidates= ['wentworth', 'granville']
# st.split(k)= ['', ' st granville nsw']
# st.split(k)= ['wentworth st ', ' nsw']
# candidates= ['cleveland', 'surry hills']
# st.split(k)= ['', ' st surry hills nsw']
# st.split(k)= ['cleveland st ', ' nsw']
# candidates= ['bourke', 'wagga wagga']
# st.split(k)= ['', ' street wagga wagga nsw']
# st.split(k)= ['bourke street ', ' nsw']
# candidates= ['warrnambool', 'koroit']
# st.split(k)= ['', ' showgrounds koroit st ', ' vic']
# st.split(k)= ['warrnambool showgrounds ', ' st warrnambool vic']
# candidates= ['docklands', 'melbourne']
# st.split(k)= ['', ' drive melbourne ', ' vic']
# st.split(k)= ['docklands drive ', ' docklands vic']
# candidates= ['goodwood', 'wayville']
# st.split(k)= ['', ' road wayville sa']
# st.split(k)= ['goodwood road ', ' sa']
# candidates= ['young', 'cowra']
# st.split(k)= ['', ' rd cowra nsw']
# st.split(k)= ['young rd ', ' nsw']
# candidates= ['perth', 'east perth']
# st.split(k)= ['nelson crescent east ', ' wa']
# st.split(k)= ['nelson crescent ', ' wa']
# candidates= ['altona', 'altona north']
# st.split(k)= ["doherty's rd cnr grieve pde ", ' north vic']
# st.split(k)= ["doherty's rd cnr grieve pde ", ' vic']
# candidates= ['ashfield', 'liverpool']
# st.split(k)= ['liverpool rd ', ' nsw']
# st.split(k)= ['', ' rd ashfield nsw']
# candidates= ['newcastle', 'newcastle west']
# st.split(k)= ['cnr king union sts ', ' west nsw']
# st.split(k)= ['cnr king union sts ', ' nsw']
# candidates= ['crawley', 'stirling']
# st.split(k)= ['stirling hwy ', ' wa']
# st.split(k)= ['', ' hwy crawley wa']
# candidates= ['woodford', 'neurum']
# st.split(k)= ['neurum road ', ' qld']
# st.split(k)= ['', ' road woodford qld']
# candidates= ['sydney', 'double bay']
# st.split(k)= ['shp  /  knox st double bay ', ' nsw']
# st.split(k)= ['shp  /  knox st ', ' sydney nsw']
# candidates= ['pimpama', 'jacobs well']
# st.split(k)= ['lot  ', ' jacobs well road ', ' qld']
# st.split(k)= ['lot  pimpama ', ' road pimpama qld']
# found suburbs for 1059 our of 1059 venues

# %%
venues_no_suburb = venues.loc[venues["suburb"].isnull(),:]
print("venues without suburbs: {}".format(len(venues_no_suburb)))
venues = venues.loc[-venues.v_code.isin(venues_no_suburb.v_code),:]
print("remaining venues: {}".format(len(venues)))
# Out:
# venues without suburbs: 0
# remaining venues: 1059

# %%
venues
# Out:
#          v_code                                         v_name  \
# 0      proxywin            win entertainment centre wollongong
# 2           med                          1 two 3 mediterranean
# 4           rus                                    170 russell
# 14          abs                             abbotsford convent
# 15          abp                              abc perth studios
# 17          aho                              abercrombie house
# 18          kqu                  aboard the kimberley quest ii
# 20          acb                                        academy
# 21          adc                                 academy cinema
# 22          aod                    academy of design australia
# 23    vaccamelb                                           acca
# 28          rou                  action paintball - rouse hill
# 29          ser                  action paintball - serpentine
# 30          amg                activ8 health and sports centre
# 31          afp               active flight paragliding bright
# 32          spa                 actt the old performance space
# 34          agr                                       adelaide
# 39          aec                  adelaide entertainment centre
# 42          afc                       adelaide festival centre
# 43        x-afc                 adelaide festival centre trust
# 44        x-aff                         adelaide film festival
# 45        x-adf                                adelaide fringe
# 53          way                           adelaide showgrounds
# 55          ats                      adelaide tandem skydiving
# 58          aqp             adventure quest paintball skirmish
# 59          awp                                adventure world
# 67          aln                            albany creek tavern
# 68          aew                    albany entertainment centre
# 71          acl                                    albert hall
# 72          ahc                                    albert hall
# ...         ...                                            ...
# 2876        wnw                         wet'n'wild water world
# 2877        cbd  whale watching sydney - bass flinders cruises
# 2878        wip                             whales in paradise
# 2887        whw                               whitewater world
# 2888        lam                         whitlam leisure centre
# 2894        wra                            wild ride australia
# 2895        wfs                                wildfire sydney
# 2899        wcc                        willoughby civic centre
# 2902        qrn                             willowbank raceway
# 2905        wbh                         wilson boathouse manly
# 2906        wev                          wimmera events centre
# 2907        wec                       win entertainment centre
# 2909        wfu                        windsor function centre
# 2912        wph                              winthrop hall uwa
# 2913        wmr                           winton motor raceway
# 2915        wiz                           wizard of oz funland
# 2916        wbg                     wollongong botanic gardens
# 2922      ~wuf~                 wollongong uni function centre
# 2925        wsg                           woodford showgrounds
# 2927        wvt                                woodvale tavern
# 2929        wow                                world of whisky
# 2932        wrx                                 wrx experience
# 2934        wsd                            wsid sydney dragway
# 2935        wye                        wyndham cultural centre
# 2940        xan                  xanadu wines - margaret river
# 2941        xup                                 xup event site
# 2947        boe                               yass showgrounds
# 2951        yon                                   yongala dive
# 2952        yol                               york on lilydale
# 2959        yjp                              yukis at the quay
#
#                                                  v_addr       lat0  \
# 0                  corner harbour and crown streets nsw -34.426220
# 2                      shop  surf parade broadbeach qld -28.035530
# 4                              russell st melbourne vic -37.811907
# 14                     st heliers street abbotsford vic -37.802170
# 15                             fielder st east perth wa -31.951680
# 17                                ophir rd bathurst nsw -33.392609
# 18               pro-fisherman's boat ramp quindalup wa -33.613940
# 20                       bunda street canberra city act -35.279020
# 21                             hindmarsh sq adelaide sa -34.923210
# 22                     ingles street port melbourne vic -37.828871
# 23                 sturt street southbank melbourne vic -37.826700
# 28        - annangrove rd cnr edwards rd rouse hill nsw -33.661080
# 29                            punrak road serpentine wa -32.378840
# 30                         penola road mount gambier sa -37.817073
# 31                                           bright vic -36.730200
# 32                         cleveland street redfern nsw -33.889410
# 34                   goldrush ballooning strathalbyn sa -35.258880
# 39        corner port road and adam street hindmarsh sa -34.909800
# 42                          king william rd adelaide sa -34.916310
# 43                          king william rd adelaide sa -34.916310
# 44                             king william rd unley sa -34.944800
# 45    1st floor ebenezer place corner rundle street ... -34.922490
# 53                                 wayville pavilion sa -34.945860
# 55                              po box  golden grove sa -34.792830
# 58                      singleton rd kurrajong east nsw -33.500140
# 59                         progress drive bibra lake wa -32.092690
# 67                     albany creek rd albany creek qld -27.345940
# 68        toll place off princess royal drive albany wa -35.029380
# 71     corner of tamar cimitiere streets launceston tas -41.432900
# 72                        commonwealth ave canberra act -35.284700
# ...                                                 ...        ...
# 2876                       pacific highway oxenford qld -27.891320
# 2877                 departs from sydney cbd sydney nsw -33.873650
# 2878                     ferny ave surfers paradise qld -27.999390
# 2887                            pacific hwy coomera qld -27.844465
# 2888                      memorial avenue liverpool nsw -33.923380
# 2894                          sydney blue mountains nsw -33.873650
# 2895  ground level overseas passenger terminal sydne... -33.873650
# 2899                      victoria avenue chatswood nsw -33.796130
# 2902                       champions way willowbank qld -27.692140
# 2905                             trafalgar st manly qld -27.451770
# 2906                    field days road longerenong vic -36.671534
# 2907    corner harbour and crown streets wollongong nsw -34.426220
# 2909                           macquarie st windsor nsw -33.610020
# 2912                            stirling hwy crawley wa -31.976629
# 2913                              fox street winton vic -36.526640
# 2915                        / hollylea road leumeah nsw -34.053220
# 2916                  northfields avenue keiraville nsw -34.407770
# 2922                 northfields avenue gwynneville nsw -34.408280
# 2925                           neurum road woodford qld -26.950380
# 2927                         trappers drive woodvale wa -31.783870
# 2929              shp  /  knox st double bay sydney nsw -33.877130
# 2932          lot  pimpama jacobs well road pimpama qld -27.812830
# 2934                       ferrers rd eastern creek nsw -33.808740
# 2935                         watton street werribee vic -37.903720
# 2940      boodjidup road xanadu wines margaret river wa -33.982600
# 2941                     wattanobbi road warnervale nsw -33.253860
# 2947                       grand junction road yass nsw -34.842214
# 2951                       narrah street alva beach qld -20.917570
# 2952                 cnr york swansea rds mt evelyn vic -31.899070
# 2959  level  overseas passenger terminal west circul... -33.858371
#
#             lng0 state            suburb
# 0     150.902150   NSW
# 2     153.432890   QLD        broadbeach
# 4     144.968272   VIC         melbourne
# 14    145.003780   VIC        abbotsford
# 15    115.873080    WA        east perth
# 17    149.518807   NSW          bathurst
# 18    115.110719    WA         quindalup
# 20    149.133250   ACT          canberra
# 21    138.606350    SA          adelaide
# 22    144.941085   VIC    port melbourne
# 23    144.966560   VIC         melbourne
# 28    150.923610   NSW        rouse hill
# 29    115.921190    WA        serpentine
# 30    140.785448    SA     mount gambier
# 31    146.960900   VIC            bright
# 32    151.203450   NSW         cleveland
# 34    138.890350    SA       strathalbyn
# 39    138.570810    SA         hindmarsh
# 42    138.598940    SA          adelaide
# 43    138.598940    SA          adelaide
# 44    138.599290    SA             unley
# 45    138.609330    SA          ebenezer
# 53    138.586910    SA          wayville
# 55    138.693640    SA      golden grove
# 58    150.809430   NSW         singleton
# 59    115.820520    WA        bibra lake
# 67    152.966430   QLD      albany creek
# 68    117.886640    WA            albany
# 71    147.141490   TAS        launceston
# 72    149.128110   ACT          canberra
# ...          ...   ...               ...
# 2876  153.313660   QLD          oxenford
# 2877  151.206890   NSW            sydney
# 2878  153.426590   QLD  surfers paradise
# 2887  153.305712   QLD           coomera
# 2888  150.911890   NSW         liverpool
# 2894  151.206890   NSW            sydney
# 2895  151.206890   NSW            sydney
# 2899  151.183090   NSW         chatswood
# 2902  152.665370   QLD        willowbank
# 2905  153.189520   QLD             manly
# 2906  142.305715   VIC       longerenong
# 2907  150.902150   NSW        wollongong
# 2909  150.817910   NSW           windsor
# 2912  115.818901    WA          stirling
# 2913  146.096210   VIC            winton
# 2915  150.824820   NSW           leumeah
# 2916  150.875830   NSW        keiraville
# 2922  150.880380   NSW       gwynneville
# 2925  152.755990   QLD            neurum
# 2927  115.787000    WA          woodvale
# 2929  151.242280   NSW        double bay
# 2932  153.292810   QLD       jacobs well
# 2934  150.866580   NSW     eastern creek
# 2935  144.657410   VIC          werribee
# 2940  115.056470    WA    margaret river
# 2941  151.440220   NSW        warnervale
# 2947  148.923009   NSW              yass
# 2951  142.702800   QLD              alva
# 2952  116.885500   VIC
# 2959  151.209548   NSW            sydney
#
# [1059 rows x 7 columns]

# %%
gmaps = googlemaps.Client(key='AIzaSyCsJnOb6VESNe9C-BXpkbrLppPA2ygCJMg')

# %%
def find_coords(st):
    
    attempted_search_res = gmaps.geocode(st)
    
    if attempted_search_res:
        res = (attempted_search_res[0]["geometry"]["location"], attempted_search_res[0]['formatted_address'])
        return res  
    else:   
        return ({'lat': None, 'lng': None}, None)  

landmark_name_venues["result"] = None
landmark_name_venues.ix[:,"result"] = landmark_name_venues.ix[:,"st"].apply(find_coords)
# Out:
# C:\Users\igork\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel\__main__.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\igork\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\indexing.py:477: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
landmark_name_venues["lng"] = landmark_name_venues.loc[:,"result"].apply(lambda x: x[0]['lng'])
landmark_name_venues["lat"] = landmark_name_venues.loc[:,"result"].apply(lambda x: x[0]['lat'])
landmark_name_venues["adr"] = landmark_name_venues.loc[:,"result"].apply(lambda x: x[1])
# Out:
# C:\Users\igork\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Users\igork\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# C:\Users\igork\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
res0 = landmark_name_venues.loc[:,["v_code","v_name","v_addr","lat0","lat", "lng0", "lng","adr"]]

# %%
res0["flagged"] = abs(res0["lat0"] - res0["lat"]) > 0.005

# %%
rr = res0[res0.flagged == True]

# %%
rr.drop("flagged",inplace=True,axis=1)
# Out:
# C:\Users\igork\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
rr.to_csv("sample_380.csv",index=False)
