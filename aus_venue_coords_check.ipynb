# %%
import googlemaps
import pandas as pd
import re
import time
from itertools import combinations
from collections import Counter, defaultdict

# %%
states_sh2lng = {"nsw": "new south wales", "vic": "victoria", "sa": "south australia", 
                 "tas": "tasmania", "qld": "queensland",
                 "wa": "western australia", "act": "australian capital territory", 
                 "nt": "northern territory"}

aus_cities = {"sydney", "melbourne", "perth", "adelaide", "brisbane", "canberra", "darwin", "hobart",
             "gold coast", "cairns", "townsville", "launceston", "geelong", "alice springs"}

states_lng2sh = {v: k for k, v in states_sh2lng.items()}

pois = ["airport", "park", "aquarium", "art gallery", "bakery", "bank", "bar", "tavern","store", "bowling alley", 
        "cafe", "brewery", "campground", "casino", "studio", "cemetery", "church", "city hall", "town hall", "concert hall", "courthouse", 
        "embassy", "gym", "hospital", "hotel", "library", "mosque", "island", "academy", "cinema", "centre",
        "movie theater", "museum", "night club", "nightclub", "pharmacy", "police", "post office", "cinemas",
        "restaurant", "school", "shopping mall", "shopping centre", "spa", "stadium", "station", "synagogue", 
        "university", "zoo", "club", "casino", "theatre", "parklands", "hotel", "rsl", "oval", "showground", "showgrounds", 
        "racecourse", "gallery", "resort", "square", "estate", "arena", "reserve", "winery", "wharf", 
        "cathedral", "plaza", "opera house", "vineyard", "farm", "aquatic centre", "gardens", "valley",
        "pavillion", "convention centre", "community centre", "point", "institute", "business centre", "castle",
        "national park", "harbour", "studios", "world", "house", "hall", "lounge", "marina", "parks"]

only_w_suburb_pois = ["cinemas", "cinema", "movie theatre", "hotel", "wharf", "world", "house", "hall", "marina"]

nonspecific_pois = ["island", "parklands", "showground", "estate", "reserve", "winery", "wharf", "vineyard", "farm", 
                   "gardens", "point", "valley", "national park", "parks"]

# %%
street_types = """alley ally arcade arc avenue ave boulevard bvd bypass bypa circuit cct close cl corner crn court
                    ct crescent cres cul-de-sac cds drive dr esplanade esp green grn grove gr highway
                    hwy junction jnc lane lane link link mews mews parade pde place pl ridge rdge road rd 
                    square sq street st terrace tce way""".split()

fake_venue_words = {"voucher", "tour", "vouchers", "tours", "various", "testing", "test", "cruise", "departs", 
                    "membership", "members", "memberships", "n/a"}

venues = pd.read_csv("aus_venues.txt", sep="\t")
nv_init = len(venues)
print("venues to process: {}".format(nv_init))

# make sure there are only single white spaces in names and addresses
for col in ["v_name", "v_addr"]:
    venues.loc[:,col] = venues.loc[:,col].str.replace("[.;-@_:#&()]"," ")
    venues.loc[:,col] = venues.loc[:,col].str.replace(r"\bmt\b","mount")
    venues.loc[:,col] = venues.loc[:,col].apply(lambda x: " ".join(str(x).strip().split()).lower())

# remove all numbers from addresses
venues.loc[:,"v_addr"] = venues.loc[:,"v_addr"].str.replace(r"\b\d+\b","")

# remove duplicates in names + addresses; some venues differ only in venue code
venues.drop_duplicates(subset=["v_name","v_addr"], inplace=True)
nv_dpl = len(venues)
print("removed duplicates, remaining venues: {}".format(nv_dpl))
# Out:
# venues to process: 3027
# removed duplicates, remaining venues: 2866

# %%
v_bad_codes = set(venues.loc[venues.v_name.isnull() | 
                   venues.v_addr.isnull() |
                   venues.v_addr.isin(["","nan","national"]) |
                   venues.lat0.isnull() | venues.lng0.isnull(),"v_code"].tolist())

print("venues with missing name, address or coordinates: {}".format(len(v_bad_codes)))

# first look for the outright suspicious venues
v_bad_codes.update(set(venues.loc[(venues["v_name"] + ' ' + venues["v_addr"]).apply(lambda x: True if set(x.split()) & 
                                                                               fake_venue_words else False), "v_code"].tolist()))
print("venues with something missing and suspicious words: {}".format(len(v_bad)))

venues = venues.loc[-venues.v_code.isin(v_bad_codes),:]
nv_nosusp = len(venues)
print("removed suspicious word venues, remaining venues: {}".format(nv_nosusp))
# Out:
# venues with missing name, address or coordinates: 28
# venues with something missing and suspicious words: 107
# removed suspicious word venues, remaining venues: 2760

# %%
subs_df = pd.read_csv("aus_subs_12APR2017.txt")
aus_suburbs = set(subs_df.loc[:,"sub"].tolist())

# %%
def find_states(st): 
    
    thestate = None    
    st_words = st.split()
    found_states = set(st_words) & set(states_sh2lng.keys())
    
    if found_states:
        thestate = " ".join(found_states)
    else:
        for candidate_state in states_lng2sh:
            res = re.search(r"\b({})\b".format(candidate_state), st)
            if res:
                thestate = states_lng2sh[candidate_state]
    
    return thestate

def find_city(st): 
    
    city = None   
    st_words = st.split()
    
    found_cities = {" ".join(w) for c in range(1,3) for w in combinations(st_words, c) if " ".join(w) in aus_cities}
    
    if found_cities:
        city = " ".join(found_cities)
    
    return city

def find_suburb(st):
    
    all_suburbs = set(subs_df["sub"].tolist()) # all australian suburbs
    st = " " + st + " "
    suburb_candidates = set()
    
    for s in all_suburbs:
        if " " + s + " " in st:
            suburb_candidates.add(s)
    
    if suburb_candidates:
        return suburb_candidates
    else:
        return None

def find_poi(st):
    
    st = " " + st + " "
    poi_candidates = set()
    
    for s in pois:
        if " " + s + " " in st:
            poi_candidates.add(s)
    
    if poi_candidates:
        return poi_candidates
    else:
        return None

# %%
cd_dict = defaultdict(set)

# look at the addresses and find states

venues["state"] = venues["v_addr"].astype(str).apply(find_states).str.upper()
venues["city"] = (venues["v_addr"].astype(str) + " " + venues["v_name"].astype(str)).apply(find_city)
venues["suburb"] = (venues["v_addr"].astype(str) + " " + venues["v_name"].astype(str)).apply(find_suburb)

for what in "state city suburb".split():
    cd_dict["with " + what] = set(venues.loc[venues[what].notnull(),"v_code"].tolist())
    cd_dict["without " + what] = set(venues.v_code.tolist()) - cd_dict["with " + what]

for k in cd_dict:
    print("venues " + k + ": {}".format(len(cd_dict[k])))
# Out:
# venues with state: 2751
# venues without state: 9
# venues with city: 948
# venues without city: 1812
# venues with suburb: 2718
# venues without suburb: 42

# %%
venues["POI"] = (venues.v_name + " " + venues.v_addr).apply(find_poi)

# %%
venues_nostate = venues.loc[venues.v_code.isin(cd_dict["without state"]),:]
# no state and no POI
v_bad_codes.update(set(venues_nostate.loc[venues_nostate.POI.isnull(),"v_code"].tolist()))

venues_nosuburb = venues.loc[venues.v_code.isin(cd_dict["without suburb"]),:]
# no suburb and no suitable POI - put these into rubbish
v_bad_codes.update(set(venues_nosuburb.loc[venues_nosuburb.POI.apply(lambda x: True if (not x) or (x & set(only_w_suburb_pois)) else False),"v_code"].tolist()))

venues = venues.loc[-venues.v_code.isin(v_bad_codes),:]
print("venues left: {}".format(len(venues)))

for k in cd_dict:
    cd_dict[k] = cd_dict[k] - v_bad_codes
# Out:
# venues left: 2735

# %%
venues["search_line"] = None
venues["suburb_upd"] = None

for row in venues.itertuples():
    
    cnd = set()
    
    # if found a street type in address, priority to suburb candidates to the right
    for street in street_types:
        if row.suburb:
            for k in row.suburb:
                lst = row.v_addr.split(street)
                if (len(lst) > 1) and (k in lst[-1]):   # i.e. if street was there
                    cnd.add(k)
        else:
            pass

    if len(cnd) == 1: # if a single candidate selected, 
        venues.ix[row.Index,"suburb_upd"] = cnd.pop()
    else:
        if row.suburb and row.state:  # if state is available, priority to suburb candidate right before state       
            for k in row.suburb:
                if (re.search(r"\b({})\b".format(" ".join([k, row.state.lower()])), row.v_addr) or
                    re.search(r"\b({})\b".format(" ".join([k, states_sh2lng[row.state.lower()]])), row.v_addr)):
                    venues.ix[row.Index,"suburb_upd"] = k
    
    # if still unclear what suburb but there's a city name, just take the city name
    if not venues.ix[row.Index,"suburb_upd"]:  # if still undefined
        if row.city:
            venues.ix[row.Index,"suburb_upd"] = row.city
    
    if not venues.ix[row.Index,"suburb_upd"]:  # if still undefined
        if row.suburb and len(row.suburb) == 1:
            venues.ix[row.Index,"suburb_upd"] = row.suburb.pop()
    
    if row.state and row.POI and venues.ix[row.Index,"suburb_upd"] and (row.POI & set(pois)):
        venues.ix[row.Index,"search_line"] = " ".join([row.v_name, venues.ix[row.Index,"suburb_upd"], row.state])
    
    if not venues.ix[row.Index,"search_line"]:
        if (not venues.ix[row.Index,"suburb_upd"]) and row.state and row.POI and (len(row.POI & set(only_w_suburb_pois)) == 0):
            venues.ix[row.Index,"search_line"] = " ".join([row.v_name, row.state])
    if not venues.ix[row.Index,"search_line"]:
         if venues.ix[row.Index,"suburb_upd"] and row.state and row.POI and (row.POI & set(only_w_suburb_pois)):
            venues.ix[row.Index,"search_line"] = " ".join([row.v_name, venues.ix[row.Index,"suburb_upd"], row.state])
    if not venues.ix[row.Index,"search_line"]:
         if venues.ix[row.Index,"suburb_upd"] and row.POI and (row.POI & set(row.v_name.split())):
            venues.ix[row.Index,"search_line"] = " ".join([row.v_name, venues.ix[row.Index,"suburb_upd"]])

# %%
print(len(venues.loc[venues.search_line.isnull()]))
venues.loc[venues.search_line.isnull()]
# Out:
# 646
#          v_code                                        v_name  \
# 2           med                         1 two 3 mediterranean
# 4           rus                                   170 russell
# 14          abs                            abbotsford convent
# 18          kqu                 aboard the kimberley quest ii
# 23    vaccamelb                                          acca
# 28          rou                 action paintball - rouse hill
# 29          ser                 action paintball - serpentine
# 31          afp              active flight paragliding bright
# 32          spa                actt the old performance space
# 34          agr                                      adelaide
# 44        x-aff                        adelaide film festival
# 45        x-adf                               adelaide fringe
# 55          ats                     adelaide tandem skydiving
# 58          aqp            adventure quest paintball skirmish
# 78          abw                              albert waterways
# 80          aly                              albury - wodonga
# 82          agl                        albury gateway village
# 84          akw                       albury kinross woolshed
# 86          sga                          albury sports ground
# 104      chaaoa             ambassador of austria's residence
# 105         aut             ambassador of austria's residence
# 106         arf                     ambassador room frankston
# 108         amb                            ambiwerra festival
# 110         amp                                  amp building
# 123         aqx                            aquatic explorer's
# 137         mbb                         art of massage beauty
# 139         asm  arthur streeton auditorium sofitel melbourne
# 163         obk                             australia outback
# 184         rgp                                avalon raceway
# 198         blo                                 balloon aloft
# ...         ...                                           ...
# 2788        vfi                                     venue 505
# 2790   vmike304                                       venue-3
# 2794        hov                                      victoria
# 2795        bff             victoria festival of motion image
# 2806        vno                                   villa noosa
# 2818        wls                              wallsend diggers
# 2821        wds                   wardrobe detox shop n learn
# 2826        wtp                    warner village theme parks
# 2834        wcd                     waterfront city docklands
# 2841        wel                       welsh's road milbrodale
# 2855        wcr                  west cowra recreation ground
# 2861        wac        western australian cricket association
# 2868        wsc               westgate sports leisure complex
# 2872        was                                wests ashfield
# 2873        cnp                                    wests city
# 2874        cwl                                 wests leagues
# 2878        wip                            whales in paradise
# 2894        wra                           wild ride australia
# 2895        wfs                               wildfire sydney
# 2902        qrn                            willowbank raceway
# 2905        wbh                        wilson boathouse manly
# 2913        wmr                          winton motor raceway
# 2915        wiz                          wizard of oz funland
# 2932        wrx                                wrx experience
# 2934        wsd                           wsid sydney dragway
# 2940        xan                 xanadu wines - margaret river
# 2941        xup                                xup event site
# 2951        yon                                  yongala dive
# 2952        yol                              york on lilydale
# 2959        yjp                             yukis at the quay
#
#                                                  v_addr       lat0  \
# 2                      shop  surf parade broadbeach qld -28.035530
# 4                              russell st melbourne vic -37.811907
# 14                     st heliers street abbotsford vic -37.802170
# 18               pro-fisherman's boat ramp quindalup wa -33.613940
# 23                 sturt street southbank melbourne vic -37.826700
# 28        - annangrove rd cnr edwards rd rouse hill nsw -33.661080
# 29                            punrak road serpentine wa -32.378840
# 31                                           bright vic -36.730200
# 32                         cleveland street redfern nsw -33.889410
# 34                   goldrush ballooning strathalbyn sa -35.258880
# 44                             king william rd unley sa -34.944800
# 45    1st floor ebenezer place corner rundle street ... -34.922490
# 55                              po box  golden grove sa -34.792830
# 58                      singleton rd kurrajong east nsw -33.500140
# 78                sunshine boulevard mermaid waters qld -28.036930
# 80                   lincon causeway albury wodonga nsw -36.090900
# 82                        lincolin causeway wadonga nsw -36.106579
# 84                          kinross court thurgoona nsw -36.037021
# 86              corner hume hwy riverina hwy albury nsw -34.829830
# 104                         somers crescent forrest act -35.313800
# 105                           talbot street forrest act -35.313800
# 106                            nepean hwy frankston vic -38.133120
# 108                         erinvale street corinda qld -27.541370
# 110                            alfred street sydney nsw -33.861820
# 123            the kingsway cronulla beach cronulla nsw -34.055380
# 137                        macpherson street bronte nsw -33.905500
# 139                        collins street melbourne vic -37.813920
# 163   pacific highway between movieworld wet n wild ... -22.755440
# 184                           old melbourne rd lara vic -38.013420
# 198                          lakeview drive carrara qld -27.999050
# ...                                                 ...        ...
# 2788                       cleveland st surry hills nsw -33.890020
# 2790                                      melbourne vic -37.813610
# 2794                                      melbourne vic -37.813610
# 2795                                      melbourne vic -37.813610
# 2806                         mary street noosaville qld -26.400240
# 2818                                      newcastle nsw -32.926700
# 2821                 sydney and surrounding suburbs nsw -31.253220
# 2826           pacific motorway oxenford gold coast qld -27.907290
# 2834            docklands drive melbourne docklands vic -37.815175
# 2841      tough dog tuff truck challenge milbrodale nsw -32.704943
# 2855                                 young rd cowra nsw -33.843010
# 2861                      nelson crescent east perth wa -31.958670
# 2868       doherty's rd cnr grieve pde altona north vic -37.836860
# 2872                          liverpool rd ashfield nsw -33.890250
# 2873              cnr king union sts newcastle west nsw -32.928620
# 2874                         old leumeah rd leumeah nsw -34.051440
# 2878                     ferny ave surfers paradise qld -27.999390
# 2894                          sydney blue mountains nsw -33.873650
# 2895  ground level overseas passenger terminal sydne... -33.873650
# 2902                       champions way willowbank qld -27.692140
# 2905                             trafalgar st manly qld -27.451770
# 2913                              fox street winton vic -36.526640
# 2915                        / hollylea road leumeah nsw -34.053220
# 2932          lot  pimpama jacobs well road pimpama qld -27.812830
# 2934                       ferrers rd eastern creek nsw -33.808740
# 2940      boodjidup road xanadu wines margaret river wa -33.982600
# 2941                     wattanobbi road warnervale nsw -33.253860
# 2951                       narrah street alva beach qld -20.917570
# 2952              cnr york swansea rds mount evelyn vic -31.899070
# 2959  level  overseas passenger terminal west circul... -33.858371
#
#             lng0 state        city  \
# 2     153.432890   QLD        None
# 4     144.968272   VIC   melbourne
# 14    145.003780   VIC        None
# 18    115.110719    WA        None
# 23    144.966560   VIC   melbourne
# 28    150.923610   NSW        None
# 29    115.921190    WA        None
# 31    146.960900   VIC        None
# 32    151.203450   NSW        None
# 34    138.890350    SA    adelaide
# 44    138.599290    SA    adelaide
# 45    138.609330    SA    adelaide
# 55    138.693640    SA    adelaide
# 58    150.809430   NSW        None
# 78    153.424720   QLD        None
# 80    146.907660   NSW        None
# 82    146.895767   NSW        None
# 84    146.997806   NSW        None
# 86    148.961460   NSW        None
# 104   149.122250   ACT        None
# 105   149.122250   ACT        None
# 106   145.124660   VIC        None
# 108   152.987770   QLD        None
# 110   151.211580   NSW      sydney
# 123   151.151590   NSW        None
# 137   151.258360   NSW        None
# 139   144.972780   VIC   melbourne
# 163   133.790850   QLD        None
# 184   144.456660   VIC   melbourne
# 198   153.361420   QLD        None
# ...          ...   ...         ...
# 2788  151.208410   NSW        None
# 2790  144.963060   VIC   melbourne
# 2794  144.963060   VIC   melbourne
# 2795  144.963060   VIC   melbourne
# 2806  153.065690   QLD        None
# 2818  151.778890   NSW        None
# 2821  146.921100   NSW      sydney
# 2826  153.317990   QLD  gold coast
# 2834  144.939212   VIC   melbourne
# 2841  150.999635   NSW        None
# 2855  148.673360   NSW        None
# 2861  115.878520    WA       perth
# 2868  144.826060   VIC        None
# 2872  151.129910   NSW        None
# 2873  151.766980   NSW        None
# 2874  150.833070   NSW        None
# 2878  153.426590   QLD        None
# 2894  151.206890   NSW      sydney
# 2895  151.206890   NSW      sydney
# 2902  152.665370   QLD        None
# 2905  153.189520   QLD        None
# 2913  146.096210   VIC        None
# 2915  150.824820   NSW        None
# 2932  153.292810   QLD        None
# 2934  150.866580   NSW      sydney
# 2940  115.056470    WA        None
# 2941  151.440220   NSW        None
# 2951  142.702800   QLD        None
# 2952  116.885500   VIC        None
# 2959  151.209548   NSW      sydney
#
#                                                  suburb   POI search_line  \
# 2                                          {broadbeach}  None        None
# 4                                  {melbourne, russell}  None        None
# 14                                         {abbotsford}  None        None
# 18                               {quindalup, kimberley}  None        None
# 23                        {melbourne, southbank, sturt}  None        None
# 28                             {annangrove, rouse hill}  None        None
# 29                                         {serpentine}  None        None
# 31                                             {bright}  None        None
# 32                                 {redfern, cleveland}  None        None
# 34                              {strathalbyn, adelaide}  None        None
# 44                                    {unley, adelaide}  None        None
# 45                                 {ebenezer, adelaide}  None        None
# 55                      {golden grove, grove, adelaide}  None        None
# 58                               {kurrajong, singleton}  None        None
# 78    {waterways, albert, waters, sunshine, mermaid ...  None        None
# 80                                    {albury, wodonga}  None        None
# 82                                    {village, albury}  None        None
# 84               {thurgoona, woolshed, kinross, albury}  None        None
# 86                                       {hume, albury}  None        None
# 104                         {forrest, somers, crescent}  None        None
# 105                                   {forrest, talbot}  None        None
# 106                                         {frankston}  None        None
# 108                                           {corinda}  None        None
# 110                                            {sydney}  None        None
# 123                                {kingsway, cronulla}  None        None
# 137                                            {bronte}  None        None
# 139                                {melbourne, collins}  None        None
# 163                                          {oxenford}  None        None
# 184                           {avalon, melbourne, lara}  None        None
# 198                                           {carrara}  None        None
# ...                                                 ...   ...         ...
# 2788                           {cleveland, surry hills}  None        None
# 2790                                        {melbourne}  None        None
# 2794                                        {melbourne}  None        None
# 2795                                        {melbourne}  None        None
# 2806                                       {noosaville}  None        None
# 2818                              {wallsend, newcastle}  None        None
# 2821                                           {sydney}  None        None
# 2826                        {oxenford, village, warner}  None        None
# 2834                             {melbourne, docklands}  None        None
# 2841                                       {milbrodale}  None        None
# 2855                                     {young, cowra}  None        None
# 2861              {east perth, crescent, perth, nelson}  None        None
# 2868                   {altona north, westgate, altona}  None        None
# 2872                              {liverpool, ashfield}  None        None
# 2873                        {newcastle, newcastle west}  None        None
# 2874                                          {leumeah}  None        None
# 2878                       {paradise, surfers paradise}  None        None
# 2894                                           {sydney}  None        None
# 2895                                           {sydney}  None        None
# 2902                                       {willowbank}  None        None
# 2905                         {trafalgar, manly, wilson}  None        None
# 2913                                      {winton, fox}  None        None
# 2915                                          {leumeah}  None        None
# 2932                             {jacobs well, pimpama}  None        None
# 2934                            {sydney, eastern creek}  None        None
# 2940                                   {margaret river}  None        None
# 2941                                       {warnervale}  None        None
# 2951                                    {yongala, alva}  None        None
# 2952    {mount evelyn, evelyn, lilydale, york, swansea}  None        None
# 2959                                           {sydney}  None        None
#
#             suburb_upd
# 2           broadbeach
# 4            melbourne
# 14          abbotsford
# 18           quindalup
# 23           melbourne
# 28          rouse hill
# 29          serpentine
# 31              bright
# 32             redfern
# 34         strathalbyn
# 44               unley
# 45            adelaide
# 55               grove
# 58           kurrajong
# 78      mermaid waters
# 80             wodonga
# 82                None
# 84           thurgoona
# 86              albury
# 104            forrest
# 105            forrest
# 106          frankston
# 108            corinda
# 110             sydney
# 123           cronulla
# 137             bronte
# 139          melbourne
# 163           oxenford
# 184               lara
# 198            carrara
# ...                ...
# 2788       surry hills
# 2790         melbourne
# 2794         melbourne
# 2795         melbourne
# 2806        noosaville
# 2818         newcastle
# 2821            sydney
# 2826          oxenford
# 2834         docklands
# 2841        milbrodale
# 2855             cowra
# 2861             perth
# 2868      altona north
# 2872          ashfield
# 2873    newcastle west
# 2874           leumeah
# 2878  surfers paradise
# 2894            sydney
# 2895            sydney
# 2902        willowbank
# 2905             manly
# 2913            winton
# 2915           leumeah
# 2932           pimpama
# 2934     eastern creek
# 2940    margaret river
# 2941        warnervale
# 2951              alva
# 2952            evelyn
# 2959            sydney
#
# [646 rows x 11 columns]

# %%
venues.loc[venues.suburb2.isnull()]
# Out:
#         v_code                               v_name  \
# 0     proxywin  win entertainment centre wollongong
# 66         aco               albany centennial oval
# 82         agl               albury gateway village
# 124        arc                   arana leagues club
# 164        azo                        australia zoo
# 223        btv             batavia marina geraldton
# 274        bic        bicentennial community centre
# 321        bor             borenore field days site
# 350        bci                    broadford circuit
# 368        bhp               bunbury hay park north
# 369        bpj                  bunbury pilot jetty
# 457        cpw            capercaillie wine company
# 560        csp                        cirque espace
# 600        cid                   cohibar habourside
# 633        coh                   coolum beach hotel
# 710        dej                         denham jetty
# 713        dep           dennis park football field
# 735        dcn                             dockside
# 752        dog                   doug jennings park
# 753      x-dog                   doug jennings park
# 856        ext        extreme driving hunter valley
# 884        fep     festival pontoon darling harbour
# 953        gom                gallery of modern art
# 958        gar              garden city interchange
# 988        ldp            girrawheen - liddell park
# 1009       gcp                 gold coast parklands
# 1069       hro                       hard rock cafe
# 1077       hhg                       hawthorn hotel
# 1133       heh     hope estate winery hunter valley
# 1190       iwl              illawarra wests leagues
# ...        ...                                  ...
# 1884       pll          port lincoln leisure centre
# 1891       ppb                prancing pony brewery
# 1912       qde                               q deck
# 1918       qpk              quad park kawana waters
# 1951       rad          radisson hotel - gold coast
# 2046       gdr        rosehill - gardens racecourse
# 2047       atu  rosehill gardens and royal randwick
# 2051       syt                roslyn packer theatre
# 2082       ryh                               ryhope
# 2089       sbb                       salamander bay
# 2115       sae                       sazon espresso
# 2162       shb        shoalhaven heads bowling club
# 2177       sbd    sir stewart bovell park busselton
# 2218       stx               southern cross stadium
# 2342       ndy                              supergp
# 2345       suc            surfair conference centre
# 2413     ~tmn~                   tamborine mountain
# 2471       atr         the atrium federation square
# 2508       tcn              the concourse chatswood
# 2509       hcn              the concourse chatswood
# 2601       mgg           the old mount gambier gaol
# 2651       tsn           the streets of northbridge
# 2663       gub                          the uni bar
# 2676       tws                  the watershed hotel
# 2768       sqk                     unsw squarehouse
# 2802       vtq    victoria quay - fremantle harbour
# 2825       fpw              warner park theme parks
# 2826       wtp           warner village theme parks
# 2883       wpl              wheeler place newcastle
# 2946       yrv                         yarra valley
#
#                                                  v_addr       lat0  \
# 0                  corner harbour and crown streets nsw -34.426220
# 66                                       lockyer ave wa -35.015420
# 82                        lincolin causeway wadonga nsw -36.106579
# 124                            dawson parade kepera qld -27.399570
# 164          steve irwin way beerwah sunshine coast qld -26.862930
# 223                                wiebbe hayes lane wa -28.768240
# 274   bicentennial drive off ben lexcon dve sunshine... -26.406170
# 321                                                 nsw -31.253220
# 350                                                 vic -37.471310
# 368             cnr parade rd bussel highway bunnury wa -33.370730
# 369    adjacent to casuarina harbour casuarina drive wa -33.319770
# 457    londons road lovedale hunter valley wine coun... -32.785770
# 560       novotel twin waters resort sunshine coast qld -26.634110
# 600        harbourside/ harbourside darling harbour nsw -33.871114
# 633                     david low way coolum queensland -26.526800
# 710                                   knight terrace wa -25.930040
# 713                     pioneer drive boyne isaland qld -23.964350
# 735   the balcony level cockle bay wharf darling par... -31.253220
# 752                  the spit main beach gold coast qld -28.017260
# 753                             the spit gold coast qld -27.939271
# 856                                                 nsw -31.253220
# 884        national maritime museum darling harbour nsw -33.872340
# 953                        stanley place south bank qld -27.476900
# 958    cnr logan and kessels roads upper mt gravatt qld -27.559990
# 988                                                  wa -27.672820
# 1009                          smith street motorway qld -27.963440
# 1069      level  harbourside centre darling harbour nsw -33.872800
# 1077                        burwood road glenferrie vic -37.822974
# 1133                                    pokolbin rd nsw -32.823750
# 1190                    hargreaves street ununderra nsw -34.451890
# ...                                                 ...        ...
# 1884                      jubilee drive lincoln cove sa -34.719530
# 1891                   u3/ simper crescent mt barker sa -35.073912
# 1912  level   q1 surfers paradise boulevard gold coa... -28.006030
# 1918                                                qld -20.917570
# 1951                  palm meadows drive gold coast qld -28.027800
# 2046    cnr james ruse drive grand avenue rose hill nsw -33.831620
# 2047                                                nsw -31.253220
# 2051                         hickson road walsh bay nsw -33.857010
# 2082  palmers rd located at the toronto exit on the ... -32.988300
# 2089         adj shopping centre bagnell beach road nsw -31.253220
# 2115                             gawler st mt barker sa -35.067440
# 2162                 shoalhaven heads rd shoalhaven nsw -34.848440
# 2177                       cnr bussell hwy vasse hwy wa -33.663860
# 2218      cnr cowlishaw st athlon drive tuggeranong act -35.415770
# 2342     surfers paradise street circuit gold coast qld -27.999030
# 2345       surfair conference centre sunshine coast qld -26.572740
# 2413                                           name qld -20.917570
# 2471  corner swanston flinders sts federation square... -37.817510
# 2508                       the theatre victoria ave nsw -33.794030
# 2509                    the concourse  victoria ave nsw -33.794030
# 2601                          margaret st mt gambier sa -37.832480
# 2651                                                 wa -31.936890
# 2663  griffith university take the smith st exit par... -27.961350
# 2676                    harbourside darling harbour nsw -33.872340
# 2768              kensington room university of nsw nsw -31.253220
# 2802                        c-shed fremantle harbour wa -32.055610
# 2825                                     gold coast qld -28.017260
# 2826           pacific motorway oxenford gold coast qld -27.907290
# 2883           next to civic theatre  hunter street nsw -32.926990
# 2946                                                vic -37.471310
#
#             lng0 state  city  \
# 0     150.902150   NSW  None
# 66    117.885110    WA  None
# 82    146.895767   NSW  None
# 124   152.961290   QLD  None
# 164   152.962320   QLD  None
# 223   114.611250    WA  None
# 274   153.110150   QLD  None
# 321   146.921100   NSW  None
# 350   144.785150   VIC  None
# 368   115.642110    WA  None
# 369   115.639130    WA  None
# 457   151.355270   NSW  None
# 560   153.099760   QLD  None
# 600   151.199042   NSW  None
# 633   153.090010   QLD  None
# 710   113.537950    WA  None
# 713   151.332450   QLD  None
# 735   146.921100   NSW  None
# 752   153.425700   QLD  None
# 753   153.425059   QLD  None
# 856   146.921100   NSW  None
# 884   151.198980   NSW  None
# 953   153.021750   QLD  None
# 958   153.081130   QLD  None
# 988   121.628310    WA  None
# 1009  153.366200   QLD  None
# 1069  151.199120   NSW  None
# 1077  145.040044   VIC  None
# 1133  151.236560   NSW  None
# 1190  150.842500   NSW  None
# ...          ...   ...   ...
# 1884  135.857460    SA  None
# 1891  138.877699    SA  None
# 1912  153.429490   QLD  None
# 1918  142.702800   QLD  None
# 1951  153.374660   QLD  None
# 2046  151.019810   NSW  None
# 2047  146.921100   NSW  None
# 2051  151.205160   NSW  None
# 2082  151.520110   NSW  None
# 2089  146.921100   NSW  None
# 2115  138.858708    SA  None
# 2162  150.737840   NSW  None
# 2177  115.359240    WA  None
# 2218  149.063230   ACT  None
# 2342  153.428670   QLD  None
# 2345  152.920590   QLD  None
# 2413  142.702800   QLD  None
# 2471  144.967540   VIC  None
# 2508  151.190400   NSW  None
# 2509  151.190400   NSW  None
# 2601  140.773290    SA  None
# 2651  115.840599    WA  None
# 2663  153.382160   QLD  None
# 2676  151.198980   NSW  None
# 2768  146.921100   NSW  None
# 2802  115.739270    WA  None
# 2825  153.425700   QLD  None
# 2826  153.317990   QLD  None
# 2883  151.772100   NSW  None
# 2946  144.785150   VIC  None
#
#                                                  suburb suburb2
# 0                                          {wollongong}    None
# 66                                    {lockyer, albany}    None
# 82                                    {village, albury}    None
# 124                                            {dawson}    None
# 164                          {irwin, beerwah, sunshine}    None
# 223                                  {hayes, geraldton}    None
# 274                          {sunshine beach, sunshine}    None
# 321                                   {field, borenore}    None
# 350                                         {broadford}    None
# 368                                      {bunbury, hay}    None
# 369                                {bunbury, casuarina}    None
# 457                          {hunter, lovedale, valley}    None
# 560                     {waters, twin waters, sunshine}    None
# 600                                           {darling}    None
# 633                                      {coolum beach}    None
# 710                                            {denham}    None
# 713                                    {field, pioneer}    None
# 735                                           {darling}    None
# 752                              {main beach, jennings}    None
# 753                                          {jennings}    None
# 856                                    {hunter, valley}    None
# 884                                           {darling}    None
# 953                                           {stanley}    None
# 958                                {logan, garden city}    None
# 988                               {liddell, girrawheen}    None
# 1009                                        {parklands}    None
# 1069                                          {darling}    None
# 1077                                {hawthorn, burwood}    None
# 1133                 {pokolbin, hunter, valley, estate}    None
# 1190                                        {illawarra}    None
# ...                                                 ...     ...
# 1884                                     {port lincoln}    None
# 1891                                         {crescent}    None
# 1912                       {paradise, surfers paradise}    None
# 1918                                   {kawana, waters}    None
# 1951                                          {meadows}    None
# 2046                       {rosehill, racecourse, ruse}    None
# 2047                               {rosehill, randwick}    None
# 2051                                           {roslyn}    None
# 2082                       {ryhope, newcastle, toronto}    None
# 2089                                   {salamander bay}    None
# 2115                                           {gawler}    None
# 2162                                 {shoalhaven heads}    None
# 2177                         {vasse, busselton, bovell}    None
# 2218                                   {southern cross}    None
# 2342                       {paradise, surfers paradise}    None
# 2345                                         {sunshine}    None
# 2413          {tamborine mountain, mountain, tamborine}    None
# 2471                               {flinders, swanston}    None
# 2508                                        {chatswood}    None
# 2509                                        {chatswood}    None
# 2601                                    {mount gambier}    None
# 2651                                      {northbridge}    None
# 2663  {griffith university, parklands, griffith, sou...    None
# 2676                                          {darling}    None
# 2768                                       {kensington}    None
# 2802                                        {fremantle}    None
# 2825                                           {warner}    None
# 2826                        {oxenford, village, warner}    None
# 2883                                {hunter, newcastle}    None
# 2946                                    {yarra, valley}    None
#
# [93 rows x 9 columns]

# %%
v_bad = pd.concat([v_bad,
                    venues.loc[venues.suburb.apply(lambda x: False if len(x)>0 else True),:]])

venues = venues.loc[-venues.v_code.isin(v_bad.v_code.tolist()),:]
nv_nosub = len(venues)
print("removed no suburb venues, remaining venues: {}".format(nv_nosub))
# Out:
# removed no suburb venues, remaining venues: 2715

# %%
poi_v_codes = ( set(venues.loc[venues.loc[:,"v_name"].apply(lambda x: True if [1 for c in range(1,3) 
                                                                    for w in combinations(x.split(), c) 
                                                                    if {" ".join(w)} & set(pois)] else False),"v_code"].tolist()) | 
set(venues.loc[venues.loc[:,"v_addr"].apply(lambda x: True if [1 for c in range(3) 
                                                                    for w in combinations(x.split(), c) 
                                                                    if {" ".join(w)} & set(pois)] else False),"v_code"].tolist()) )

# %%
nv_pois = len(poi_v_codes)
print("venues with POIs in name or address: {}".format(nv_pois))
# Out:
# venues with POIs in name or address: 1883

# %%
nopoi_v_codes = set(venues.v_code.tolist()) - poi_v_codes

# %%
venues_poi = venues.loc[venues.v_code.isin(poi_v_codes),:]
venues_poi.head()
# Out:
#      v_code                               v_name  \
# 0  proxywin  win entertainment centre wollongong
# 1   level 2                          newtown rsl
# 3       stk        1300smiles stadium townsville
# 5       mmr     2012 bmw magic millions race day
# 6       ahb                    21 arms nightclub
#
#                                               v_addr      lat0       lng0  \
# 0               corner harbour and crown streets nsw -34.42622  150.90215
# 1        petersham rsl club  enmore road newtown nsw -33.89842  151.17648
# 3             golf links drive kirwan townsville qld -19.30748  146.71389
# 5  gold coast turf club racecourse drive bundall qld -28.01086  153.40712
# 6                armstrong street north ballarat vic -37.56055  143.85635
#
#   state        city                        suburb
# 0   NSW        None                  {wollongong}
# 1   NSW        None  {petersham, newtown, enmore}
# 3   QLD  townsville          {townsville, kirwan}
# 5   QLD        None         {racecourse, bundall}
# 6   VIC        None         {ballarat, armstrong}

# %%
venues_nopoi = venues.loc[venues.v_code.isin(nopoi_v_codes),:]
venues_nopoi.head()
# Out:
#    v_code                 v_name                             v_addr  \
# 2     med  1 two 3 mediterranean   shop  surf parade broadbeach qld
# 4     rus            170 russell           russell st melbourne vic
# 14    abs     abbotsford convent   st heliers street abbotsford vic
# 15    abp      abc perth studios           fielder st east perth wa
# 17    aho      abercrombie house              ophir rd bathurst nsw
#
#          lat0        lng0 state       city                          suburb
# 2  -28.035530  153.432890   QLD       None                    {broadbeach}
# 4  -37.811907  144.968272   VIC  melbourne            {melbourne, russell}
# 14 -37.802170  145.003780   VIC       None                    {abbotsford}
# 15 -31.951680  115.873080    WA      perth             {east perth, perth}
# 17 -33.392609  149.518807   NSW       None  {abercrombie, ophir, bathurst}

# %%
venues_w_poi_name.loc[venues_w_poi_name.state.isnull(),"state"] = \
    venues_w_poi_name.loc[venues_w_poi_name.state.isnull(),"state"].fillna("")

venues_w_poi_name["search_line"] = venues_w_poi_name["v_name"] + " " + venues_w_poi_name["state"]

venues = venues.loc[-venues.v_code.isin(venues_w_poi_name.v_code.tolist()),:]

venues_poi_addr.loc[venues_poi_addr.state.isnull(),"state"] = venues_poi_addr.loc[venues_poi_addr.state.isnull(),"state"].fillna("")


venues_poi_addr["search_line"] = venues_poi_addr["v_addr"] + " " + venues_poi_addr["state"] 

# remove these venues
venues = venues.loc[-venues.v_code.isin(venues_poi_addr.v_code),:]

venues_w_poi = pd.concat([venues_w_poi_name, venues_poi_addr])

# %%
venues_w_poi.drop(["city","state"], inplace=True, axis=1)
print("venues with some POI: {}".format(len(venues_w_poi)))
print("venues left: {}".format(len(venues)))
# Out:
# venues with some POI: 1587
# venues left: 975

# %%
venues["suburb"] = None

for i, row in enumerate(venues.itertuples()):
    
    candidates = []
    
    s = set(subs_df.loc[subs_df.state == row.state,"sub"].tolist())
   
    oneword_suburbs = [sb for sb in s if len(sb.split()) == 1]
    
    st = str(row.v_addr).strip()
    
    for su in oneword_suburbs:
        if su in st.split():
            candidates.append(su)
    
    twoword_suburbs = [sb for sb in s if len(sb.split()) == 2]
    
    for su in twoword_suburbs:
        aw = st.split()
        if su in [w + " " + aw[i + 1] for i, w in enumerate(aw) if i + 1 < len(aw)]:
            candidates.append(su)
            
    threeword_suburbs = [sb for sb in s if len(sb.split()) == 2]
    for su in threeword_suburbs:
        aw = st.split()
        if su in [w + " " + aw[i + 1] + " " + aw[i + 2] for i, w in enumerate(aw) if i + 2 < len(aw)]:
            candidates.append(su)
    
    if len(candidates) > 1:
        for k in candidates:
            if st.split(k):
                for part in st.split(k):
                    if set(part.split()) & set(street_types):
                        candidates = [k]
                    
    venues.ix[i, "suburb"] = ",".join(candidates)
    
print("found suburbs for {} out of {} venues".format(sum(venues.suburb.notnull()), len(venues)))
# Out:
# found suburbs for 975 out of 1643 venues

# %%
venues_no_suburb = venues.loc[(venues["suburb"] == "") | venues["suburb"].isnull(),:]

venues_no_suburb_w_city = venues_no_suburb.loc[venues_no_suburb.loc[:,"city"].notnull(),:]
venues_no_suburb_w_city["search_line"] = venues_no_suburb_w_city["v_name"] + " " + venues_no_suburb_w_city["city"]

venues_no_suburb_w_city.drop(["state", "city"], axis=1, inplace=True)

venues_no_suburb = venues_no_suburb.loc[-venues_no_suburb.v_code.isin(venues_no_suburb_w_city.v_code),:]

# collect all baddies
v_bad = pd.concat([v_bad, venues_no_suburb.drop(["state", "city", "suburb"], axis=1)])

venues = venues.loc[-venues.v_code.isin(venues_no_suburb.v_code),:]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
venues.loc[venues.loc[:,"state"].isnull(),"state"] = venues.loc[venues.loc[:,"state"].isnull(),"state"].fillna("")
venues.loc[venues.loc[:,"v_name"].isnull(),"v_name"] = venues.loc[venues.loc[:,"v_name"].isnull(),"v_name"].fillna("")

# %%
venues["search_line"] = venues["v_name"] + " " + venues["suburb"] + " " + venues["state"]

# %%
venues = pd.concat([venues, venues_no_suburb_w_city])
Counter(venues.search_line)
# Out:
# Counter({'1 two 3 mediterranean broadbeach QLD': 1,
#          '170 russell melbourne VIC': 1,
#          'abbotsford convent abbotsford VIC': 1,
#          'abc perth studios east perth WA': 1,
#          'abercrombie house ophir NSW': 1,
#          'aboard the kimberley quest ii quindalup WA': 1,
#          'academy canberra ACT': 1,
#          'academy cinema hindmarsh SA': 1,
#          'academy of design australia port melbourne VIC': 1,
#          'acca melbourne VIC': 1,
#          'action paintball - rouse hill rouse hill NSW': 1,
#          'action paintball - serpentine serpentine WA': 1,
#          'activ8 health and sports centre mount gambier SA': 1,
#          'active flight paragliding bright bright VIC': 1,
#          'actt the old performance space cleveland NSW': 1,
#          'adelaide entertainment centre hindmarsh SA': 1,
#          'adelaide festival centre adelaide SA': 1,
#          'adelaide festival centre trust adelaide SA': 1,
#          'adelaide film festival unley SA': 1,
#          'adelaide fringe ebenezer SA': 1,
#          'adelaide showgrounds wayville SA': 1,
#          'adelaide strathalbyn SA': 1,
#          'adelaide tandem skydiving golden grove SA': 1,
#          'adventure quest paintball skirmish singleton NSW': 1,
#          'adventure world bibra lake WA': 1,
#          'albany creek tavern albany creek QLD': 1,
#          'albany entertainment centre albany WA': 1,
#          'albert hall canberra ACT': 1,
#          'albert hall launceston TAS': 1,
#          'albert waterways mermaid waters QLD': 1,
#          'albury - wodonga albury NSW': 1,
#          'albury entertainment centre albury NSW': 1,
#          'albury kinross woolshed thurgoona NSW': 1,
#          'albury sports ground albury NSW': 1,
#          'altona sport leisure centre altona VIC': 1,
#          "ambassador of austria's residence forrest ACT": 2,
#          'ambassador room frankston frankston VIC': 1,
#          'amber lounge melbourne VIC': 1,
#          'ambiwerra festival corinda QLD': 1,
#          'amp building sydney NSW': 1,
#          'anesi lounge beverly hills NSW': 1,
#          "aquatic explorer's cronulla NSW": 1,
#          'arcadia twin cinema boree NSW': 1,
#          'art of massage beauty bronte NSW': 1,
#          'arthur streeton auditorium sofitel melbourne melbourne VIC': 1,
#          'arts centre melbourne st kilda VIC': 1,
#          'atherton merriland hall atherton QLD': 1,
#          'auchendarroch house mount barker SA': 1,
#          'augusta marina margaret river WA': 1,
#          'australia outback oxenford QLD': 1,
#          'australian botanic gardens acton ACT': 1,
#          'australian centre for christianity culture barton ACT': 1,
#          'australian equine and livestock event centre tamworth NSW': 1,
#          'australian equine and livestock events centre aelec goonoo goonoo NSW': 1,
#          'avalon raceway melbourne VIC': 1,
#          'ballarat - ballarat showgrounds creswick VIC': 1,
#          'balloon aloft carrara QLD': 1,
#          'balloon aloft phillip ACT': 1,
#          'ballymore herston QLD': 1,
#          'bangarra studio the rocks NSW': 1,
#          'barbagallo raceway neerabup WA': 1,
#          'bardon conference venue bardon QLD': 1,
#          'barleigh ranch raceway raymond terrace NSW': 1,
#          'barleycorn brewers oakleigh south VIC': 1,
#          'baroque - katoomba katoomba NSW': 1,
#          'bathers beach house fremantle WA': 2,
#          'bathurst memorial entertainment centre bathurst NSW': 1,
#          'bathurst panthers bathurst NSW': 1,
#          'batman fawkner inn launceston TAS': 1,
#          'beaufort beaufort VIC': 1,
#          'beechboro bosnian centre beechboro WA': 1,
#          'bega - bega showgrounds bega NSW': 1,
#          'bega recreational ground bega NSW': 1,
#          'bell tower inn ballarat VIC': 1,
#          'belmore sports ground belmore NSW': 1,
#          'belongil fields byron bay NSW': 1,
#          'belvoir amphitheatre upper swan WA': 1,
#          'belvoir function centre upper swan WA': 1,
#          'belvoir valley ampitheatre upper swan WA': 1,
#          'bendigo 2004 commonwealth youth games bendigo VIC': 1,
#          'bendigo bendigo VIC': 1,
#          'bendigo kangaroo flat leisure centre kangaroo flat VIC': 1,
#          'bendigo regional athletics facility spring gully VIC': 1,
#          'bentinck woodend VIC': 1,
#          'beverley race track beverley WA': 1,
#          'beyond fear perth WA': 1,
#          'big pineapple complex nambour QLD': 1,
#          'big red bash music festival birdsville QLD': 1,
#          'billboard the venue melbourne VIC': 1,
#          'bille brown studio south brisbane QLD': 1,
#          'billy tea bush safaris cairns QLD': 1,
#          'birch carroll coyle cinema - coffs harbour coffs harbour NSW': 1,
#          'bird’s basement melbourne VIC': 1,
#          'blacktown arts centre blacktown NSW': 1,
#          'blue fire cruises surfers paradise QLD': 1,
#          'boardwalk at fishingboat harbour fremantle WA': 1,
#          "bobby mcgee's melbourne VIC": 1,
#          'bobby mcgees niteclub melbourne VIC': 1,
#          'boiler shop honeysuckle workshops merewether NSW': 1,
#          'bombay rock townsville QLD': 1,
#          'bondi pavilion bondi beach NSW': 1,
#          'boranup forest karridale WA': 1,
#          'borden pavilion borden WA': 1,
#          'bordertown showgrounds naracoorte SA': 1,
#          'botanical gardens adelaide SA': 1,
#          'bourgie upstairs melbourne VIC': 1,
#          'bowman hall blacktown NSW': 1,
#          'brighton concert hall north brighton SA': 1,
#          'brisbane entertainment centre boondall QLD': 1,
#          'brisbane entertainment centre brisbane QLD': 1,
#          'brisbane five in one brisbane QLD': 1,
#          'brisbane international speedway archerfield QLD': 1,
#          'brisbane riverstage brisbane QLD': 1,
#          'brisbane showgrounds bowen hills QLD': 1,
#          'brotzeit 140 perth WA': 1,
#          'brown alley melbourne VIC': 1,
#          'buderim tavern buderim QLD': 1,
#          'bunbury pilot jetty casuarina WA': 1,
#          'bunbury regional entertainment centre bunbury WA': 2,
#          'bunbury speedway north boyanup WA': 1,
#          'bundaberg - kendalls flat bundaberg QLD': 1,
#          'bundy agro trend grounds bundaberg QLD': 1,
#          'bungy australia southport QLD': 1,
#          'burdekin memorial hall ayr QLD': 1,
#          'burnie - burnie sports ground burnie,upper burnie TAS': 1,
#          'bus bay margaret river WA': 1,
#          'bushwacker ecotours brisbane QLD': 1,
#          'busselton jetty busselton WA': 1,
#          'byron bay community hall byron bay NSW': 1,
#          'c ex coffs coffs harbour NSW': 1,
#          'caboolture memorial hall beerburrum,caboolture QLD': 1,
#          'caboolture showgrounds caboolture QLD': 1,
#          'caffe acqua mount barker SA': 1,
#          'cairns international tennis centre cairns QLD': 1,
#          'cairns showgrounds mulgrave QLD': 1,
#          'caloundra music festival kings beach QLD': 1,
#          'camberwell centre camberwell VIC': 1,
#          'camden civic centre camden NSW': 1,
#          'camden valley way elderslie NSW': 1,
#          'camp shortland newcastle NSW': 1,
#          'campbell’s cove the rocks NSW': 1,
#          'canberra equestrian centre chapman ACT': 1,
#          'canberra glassworks kingston ACT': 1,
#          'canberra hockey centre lyneham ACT': 1,
#          "canberra's parliamentary triangle parkes ACT": 1,
#          'capalaba - cnr moreton bay redland bay roads capalaba QLD': 1,
#          'cape leeuwin lighthouse augusta WA': 1,
#          'cape mentelle vineyards margaret river WA': 1,
#          'capella cultural centre capella QLD': 1,
#          'capercaillie wine company lovedale NSW': 1,
#          'capital entertainment centre wagga wagga NSW': 1,
#          'capitol perth WA': 1,
#          'cardiff panthers cardiff NSW': 1,
#          'cardinia cultural centre pakenham VIC': 1,
#          "caringbah bizzo's caringbah NSW": 1,
#          'caringbah bizzos caringbah NSW': 1,
#          'carr and kleemann chapel mount barker SA': 1,
#          'carriageworks - bay 17 eveleigh NSW': 1,
#          'carriageworks - bay 20 eveleigh NSW': 1,
#          'carriageworks 17 eveleigh NSW': 1,
#          'castle bay beach dunsborough WA': 1,
#          'castle hill showgrounds - sydney castle hill NSW': 1,
#          'castle hill tavern castle hill NSW': 1,
#          'catani gardens st kilda VIC': 1,
#          'cawarral recreation grounds cawarral QLD': 1,
#          'caxton street petrie terrace QLD': 1,
#          'centenary hall norlane VIC': 1,
#          'centennial vineyards bowral NSW': 1,
#          'chamber music packages canberra ACT': 1,
#          'chapel off chapel prahran VIC': 1,
#          'chatswood civic centre chatswood NSW': 1,
#          'cheeky food group surry hills NSW': 1,
#          'cheeky monkey brewery margaret river WA': 1,
#          'cheese making workshop north sydney NSW': 1,
#          'chevron festival gardens perth WA': 1,
#          'chifley at lennons brisbane QLD': 1,
#          'chill on ice ski lodge southbank VIC': 1,
#          'cia studios perth WA': 1,
#          'circular quay precinct sydney NSW': 1,
#          'circular quay sydney NSW': 1,
#          'circus arts byron bay byron bay NSW': 1,
#          'citipointe centre mansfield QLD': 1,
#          'clairault streicker wines wilyabrup WA': 1,
#          'claremont shwogrounds claremont WA': 1,
#          'cloudland fortitude valley QLD': 1,
#          'coach horses ringwood VIC': 1,
#          'code red laser ruse NSW': 1,
#          'coffs harbour showgrounds coffs harbour NSW': 1,
#          'colac botanical gardens colac VIC': 1,
#          'colac otway performing arts and cultural centre colac VIC': 1,
#          'collegians sporting complex figtree NSW': 1,
#          'colo heights colo heights NSW': 1,
#          'colonial brewery margaret river WA': 1,
#          'comfort inn haven marina glenelg north SA': 1,
#          'commonwealth place canberra ACT': 1,
#          'como house and garden south yarra VIC': 1,
#          'cooloola safaris noosa heads QLD': 1,
#          'coonawarra memorial hall coonawarra SA': 1,
#          'cornerstone college adelaide SA': 1,
#          'corridor newtown newtown NSW': 1,
#          'coutts commercial tavern ayr QLD': 1,
#          'creatures nextdoor next to little creatures brewery fremantle WA': 1,
#          'criterion tavern brisbane QLD': 1,
#          'croatian catholic centre melbourne ardeer VIC': 1,
#          'crocosaurus cove mitchell NT': 1,
#          'cronulla cinema centre cronulla NSW': 1,
#          'crown perth burswood WA': 1,
#          'crown perth studio 2 burswood WA': 1,
#          'crown promenade melbourne VIC': 1,
#          'crown showroom melbourne VIC': 1,
#          'crown studio 3 melbourne VIC': 1,
#          'cub malthouse southbank VIC': 1,
#          'cullen wines wilyabrup WA': 1,
#          'cultural centre wallcliffe rd margaret river margaret river WA': 1,
#          'cummings room newcastle NSW': 1,
#          'currumbin wildlife sanctuary currumbin QLD': 1,
#          'customs house brisbane QLD': 1,
#          'customs house sydney NSW': 1,
#          'dalkieth hall dalkeith WA': 1,
#          'dance central surry hills NSW': 1,
#          'darling harbour foreshore sydney NSW': 1,
#          'darwin showgrounds winnellie NT': 1,
#          'daveys frankston VIC': 1,
#          'deception bay tavern deception bay QLD': 1,
#          "delta force bonney's baldivis WA": 1,
#          'dendy cinema brisbane QLD': 1,
#          'dendy opera quays sydney NSW': 1,
#          'deniliquin deniliquin NSW': 1,
#          'denmark civic centre albany WA': 1,
#          'derwent entertainment centre glenorchy TAS': 1,
#          "devil's lair forest grove WA": 1,
#          'ding dong lounge melbourne VIC': 2,
#          'dingley village dingley village VIC': 1,
#          'dizingof melbourne VIC': 1,
#          'docklands studios studio 2 docklands VIC': 1,
#          'doltone house pyrmont pyrmont NSW': 1,
#          'doltone house sylvania waters sylvania waters NSW': 1,
#          "dom's cocktail lounge penrith NSW": 1,
#          'domain tennis centre hobart TAS': 1,
#          'domaine chandon coldstream VIC': 1,
#          'downstairs at the maj perth WA': 1,
#          'dracula’s haunted house surfers paradise QLD': 1,
#          'dragon city lanes bendigo VIC': 1,
#          'dreamworld coomera QLD': 1,
#          'dromoland house  ': 1,
#          'dromoland house GEELONG': 1,
#          'dubbo civic centre dubbo NSW': 1,
#          'duncraig stud middle swan WA': 1,
#          'dunsborough tavern naturaliste WA': 1,
#          'dunston playhouse adelaide SA': 1,
#          'eagle bay brewing co eagle bay WA': 1,
#          'earthcore queensland brisbane QLD': 1,
#          'earthcore victoria undera VIC': 1,
#          'earthwise centre subiaco WA': 1,
#          'east end cellars adelaide SA': 1,
#          'eastern creek eastern creek NSW': 1,
#          'eastsail rushcutters bay NSW': 1,
#          'eat street markets hamilton,brisbane QLD': 1,
#          'echuca fonterra sports entertainment centre echuca VIC': 1,
#          'edmund rice performing arts centre erpac south brisbane QLD': 1,
#          'electric playground complex fortitude valley QLD': 1,
#          'elephant rock moogerah,boonah QLD': 1,
#          'elite function centre earlwood NSW': 1,
#          'elysian fields canungra canungra QLD': 1,
#          'empire room fitzgerald WA': 1,
#          'end to end building collingwood VIC': 1,
#          'enoteca adelaide SA': 1,
#          'erina centre erina,erina fair NSW': 1,
#          'essendon ukrainian house essendon VIC': 1,
#          'ettamogah pub table top NSW': 1,
#          'eugene goossens hall ultimo NSW': 2,
#          'eurobar northbridge WA': 1,
#          "evan's tate wines margaret river WA": 1,
#          'event centre penrith panthers penrith NSW': 1,
#          'evolution prahran VIC': 1,
#          'exclusive fashion experience paddington NSW': 1,
#          'extreme driving seymour seymour VIC': 1,
#          'extreme driving tailem bend tailem bend SA': 1,
#          'extreme driving willowbank willowbank QLD': 1,
#          'extreme driving york york WA': 1,
#          'fairbridge village pinjarra WA': 1,
#          'fairfax studio st kilda VIC': 1,
#          'fairfield showgrounds smithfield NSW': 1,
#          'fairylands ballarat wendouree VIC': 1,
#          'farmhouse function centre melbourne VIC': 1,
#          'feast! fine foods adelaide SA': 1,
#          'federation concert hall hobart TAS': 1,
#          'federation conference centre surry hills surry hills NSW': 1,
#          'festival hall west melbourne VIC': 1,
#          'fish n fun charters main beach QLD': 1,
#          'fit sistas braddon ACT': 1,
#          'fitzgerald st south yarra south yarra VIC': 1,
#          "fitzy's loganholme loganholme QLD": 1,
#          'fix live rockdale NSW': 1,
#          'flight experience adelaide north adelaide SA': 1,
#          'flight experience brisbane newstead QLD': 1,
#          'flight experience perth northbridge WA': 1,
#          'floating images karalee QLD': 1,
#          'forrest place perth WA': 1,
#          'fort denison sydney NSW': 1,
#          'fort scratchley newcastle east NSW': 1,
#          'fortyfivedownstairs melbourne VIC': 1,
#          'forum melbourne melbourne VIC': 2,
#          'fowlers live adelaide SA': 1,
#          "fowlers' live adelaide SA": 1,
#          'frankston arts centre frankston VIC': 1,
#          'frankston cinema frankston VIC': 1,
#          'freedom wheels woombye QLD': 1,
#          'freemasons grand hall brisbane QLD': 1,
#          'fremantle arts centre - front garden fremantle WA': 1,
#          'fremantle boat harbour fremantle WA': 1,
#          'friday flat thredbo NSW': 1,
#          'functions on chapel prahran VIC': 1,
#          'gasworks building perth WA': 1,
#          'gateway adelaide SA': 1,
#          'gateway lakes - wodonga wodonga VIC': 1,
#          'geelong showgrounds east geelong VIC': 2,
#          'geraldton - eadon-clarke complex geraldton WA': 1,
#          'giant dwarf cleveland NSW': 1,
#          'gilhooleys downtown brisbane brisbane QLD': 1,
#          'gilligans cairns QLD': 1,
#          'gladstone entertainment centre gladstone QLD': 1,
#          'gladstone pcyc gladstone QLD': 1,
#          'glasshouse port macquarie port macquarie NSW': 1,
#          'glen willow sporting complex mudgee NSW': 1,
#          'glenelg beach glenelg SA': 1,
#          'glenmore tavern yaamba QLD': 1,
#          'glenworth valley glenworth valley NSW': 2,
#          'go wild ballooning coldstream coldstream VIC': 1,
#          'gorman house arts centre ainslie ACT': 1,
#          'government house ballroom perth perth WA': 1,
#          'government house sydney NSW': 1,
#          'gpo melbourne melbourne VIC': 1,
#          'grafton community hall grafton NSW': 1,
#          'grafton showgrounds grafton NSW': 1,
#          'granada tavern berriedale TAS': 1,
#          'grand hyatt melbourne melbourne VIC': 1,
#          'grand marquee epic mitchell ACT': 1,
#          'grand xanadu marquee docklands VIC': 1,
#          'greystanes manor bendigo bendigo VIC': 1,
#          'griffith - railway street griffith NSW': 1,
#          'gymea tradies gymea NSW': 1,
#          'gympie muster amamoor QLD': 1,
#          'hall polocrosse grounds hall ACT': 1,
#          'hamer hall arts centre melbourne st kilda VIC': 1,
#          'hamilton hamilton QLD': 1,
#          'harold lobb newcastle NSW': 1,
#          'harts mill port adelaide SA': 1,
#          'harvey road tavern gladstone QLD': 1,
#          'healesville sanctuary badger creek VIC': 1,
#          "her majesty's brisbane QLD": 1,
#          'heritage village rockhampton rockhampton QLD': 1,
#          'hidden valley raceway berrimah NT': 1,
#          'hidden valley raceway darwin NT': 1,
#          'high ‘n’ wild katoomba katoomba NSW': 1,
#          'highfields cultural centre highfields QLD': 1,
#          'hillarys boat harbour hillarys WA': 1,
#          'hilton surfers paradise surfers paradise QLD': 1,
#          'hilton sydney sydney NSW': 1,
#          'hmb basement brisbane QLD': 1,
#          'hms huon quays hobart TAS': 1,
#          'hobart - regatta grounds hobart TAS': 1,
#          'holden performance driving centre norwell QLD': 1,
#          'holdfast shores marina glenelg SA': 1,
#          'holiday inn darwin the esplanade darwin NT': 1,
#          'honeysuckle markets merewether NSW': 1,
#          'hopman cup memberships perth WA': 1,
#          'horseworld sydney maraylya NSW': 1,
#          'hot air balloon cairns surfers paradise QLD': 1,
#          'hot air balloon gold coast surfers paradise QLD': 1,
#          'hot shots paintball anakie VIC': 1,
#          'hot shots photography fyshwick ACT': 1,
#          'hoyts george st sydney NSW': 1,
#          'hq adelaide adelaide SA': 1,
#          "hugo's lounge kings cross NSW": 1,
#          'hummer limousines experience melbourne VIC': 1,
#          'hummer limousines experience sydney NSW': 1,
#          'hunter room newcastle NSW': 1,
#          'hunter street mall newcastle newcastle NSW': 1,
#          'hunter valley gardens pokolbin NSW': 1,
#          'huon quays hobart TAS': 1,
#          'hurstville entertainment centre hurstville NSW': 1,
#          'hyatt regency coolum coolum beach QLD': 1,
#          'hyperdome loganholme QLD': 1,
#          'icc sydney exhibition centre sydney NSW': 1,
#          'icebar melbourne melbourne VIC': 1,
#          'iceworld boondall sandgate QLD': 1,
#          'illawarra fly treetop adventures knights hill NSW': 1,
#          'illawarra performing arts centre wollongong NSW': 1,
#          'inferno traralgon VIC': 1,
#          'ingham shire hall ingham QLD': 1,
#          'intercontinental adelaide adelaide SA': 1,
#          'international college of management manly NSW': 1,
#          'ipswich civic centre limestone,ipswich QLD': 1,
#          'italianicious espresso company australia niangala NSW': 1,
#          'iventure card australia - nsw sydney NSW': 1,
#          'iventure card australia - qld brisbane QLD': 1,
#          'iventure card australia - tas hobart TAS': 1,
#          'iventure card australia - vic melbourne VIC': 1,
#          "ivory's rock conference centre peak crossing QLD": 1,
#          'ivy sydney NSW': 1,
#          'iwaki auditorium southbank,melbourne VIC': 1,
#          'jack smiths lane lexton lexton VIC': 1,
#          "jason coleman's ministry of dance north melbourne VIC": 1,
#          'jenolan caves jenolan NSW': 1,
#          'jet flight simulator surfers paradise QLD': 1,
#          'jewel caves deepdene WA': 1,
#          'jindabyne memorial hall jindabyne NSW': 1,
#          'joan sutherland centre penrith NSW': 1,
#          'john coles fly fishing balgowlah,north balgowlah NSW': 1,
#          'john dunmore lang place canberra canberra ACT': 1,
#          'judith wright centre fortitude valley QLD': 1,
#          'judith wright centre of contemporary arts fortitude valley QLD': 1,
#          'k shed queen victoria market melbourne VIC': 1,
#          'kalamunda performing arts centre kalamunda WA': 1,
#          'kallangur tavern kallangur QLD': 1,
#          'karnak playhouse miallo QLD': 1,
#          'karova lounge ballarat ballarat VIC': 1,
#          'kartatak raceway arncliffe NSW': 1,
#          'katoomba showgrounds katoomba NSW': 1,
#          'kawana community hall buddina QLD': 1,
#          'kay street entertainment complex traralgon VIC': 1,
#          'kelly’s café panthers penrith NSW': 1,
#          'kendal slates bundaberg bundaberg QLD': 1,
#          'kermont hall – morwell morwell VIC': 1,
#          'kgv recreation centre the rocks NSW': 1,
#          'kilcoy memorial hall kilcoy,kennedy QLD': 1,
#          'killarney recreation grounds killarney QLD': 1,
#          'kindred studios yarraville VIC': 1,
#          'kingston butter factory kingston QLD': 1,
#          'kirkton road lower belford hunter valley region lower belford NSW': 1,
#          'kosmopolitan docklands VIC': 1,
#          'kryal castle ballarat VIC': 1,
#          'kulkurt volcano crater tatyoon VIC': 1,
#          'kununurra - polocross grounds kununurra WA': 1,
#          'kyneton showgrounds kyneton VIC': 1,
#          'la di da melbourne VIC': 1,
#          'la trobe at beechworth beechworth VIC': 1,
#          'lake breeze wines langhorne creek SA': 1,
#          'lake macquarie performing arts centre warners bay NSW': 1,
#          'lake wyangan griffith boorga NSW': 1,
#          'laman street newcastle newcastle NSW': 1,
#          'langhorn creek airfield adelaide SA': 1,
#          'latrobe ballroom melbourne VIC': 1,
#          'latrobe pac traralgon VIC': 1,
#          'lavender cottage and manor blackheath NSW': 1,
#          'lavington sports ground albury albury NSW': 1,
#          'legislative council chamber brisbane QLD': 1,
#          'level 3 crown entertainment complex southbank VIC': 1,
#          "life's elements cardigan VIC": 1,
#          'lightspace fortitude valley QLD': 1,
#          'lindt chocolate café sydney NSW': 1,
#          'lismore circus site lismore NSW': 1,
#          'live crown entertainment complex melbourne VIC': 1,
#          'lock 11 mildura VIC': 1,
#          'logan diggers logan central QLD': 1,
#          'logan entertainment centre logan central QLD': 1,
#          'logan metro sports complex browns plains QLD': 1,
#          'lonestar tavern mermaid waters QLD': 1,
#          'longworth house newcastle NSW': 1,
#          'lorne lorne VIC': 1,
#          'lotterywest film festival joondalup,somerville WA': 1,
#          'love machine south yarra VIC': 1,
#          'mackay - showgrounds mackay QLD': 1,
#          'mackay pcyc north mackay QLD': 1,
#          'macquarie inn dubbo NSW': 1,
#          'madame tussauds sydney sydney NSW': 1,
#          'madew wines lake george NSW': 1,
#          'maia central pier docklands VIC': 1,
#          'manchester lane melbourne VIC': 1,
#          'manhattan superbowl liverpool liverpool NSW': 1,
#          'manhattan superbowl mascot mascot NSW': 1,
#          'manly beach manly NSW': 1,
#          'manly sea life sanctuary manly NSW': 1,
#          'manly youth centre manly NSW': 1,
#          'mansfield tavern mansfield QLD': 1,
#          'mantra on queen brisbane QLD': 1,
#          'margaret river visitor centre margaret river WA': 1,
#          "mariner's cover marina main beach QLD": 1,
#          'mariners cove main beach QLD': 1,
#          'marion bay marion bay TAS': 1,
#          'maroochydore regional football complex maroochydore QLD': 1,
#          'marquee the star pyrmont NSW': 1,
#          'marrara sports complex marrara NT': 1,
#          'martin place sydney sydney NSW': 1,
#          'marulan driver training centre marulan NSW': 1,
#          'mary mackillop place north sydney NSW': 1,
#          'mchenry hohnen vintners forest grove WA': 1,
#          'mclarens landing main beach QLD': 1,
#          'meat market arts house main pavilion north melbourne VIC': 1,
#          'meeniyan hall meeniyan VIC': 1,
#          'melbourne 4 x 4 training and proving ground werribee VIC': 1,
#          'melbourne 4x4 training and providing ground werribee VIC': 1,
#          'melbourne 4x4 training and proving ground melbourne VIC': 1,
#          'melbourne five in one melbourne VIC': 1,
#          'melbourne recital centre southbank VIC': 1,
#          'melbourne river cruises docklands VIC': 1,
#          'melbourne showgrounds ascot vale VIC': 1,
#          'melbourne star observation wheel melbourne,docklands VIC': 1,
#          'memorial drive north adelaide SA': 1,
#          'merchandise sydney NSW': 1,
#          'meredith supernatural amphitheatre meredith VIC': 1,
#          'merlin annual pass sydney NSW': 2,
#          'metcalfe playhouse northbridge WA': 1,
#          'metro arts brisbane QLD': 2,
#          'metro city northbridge WA': 1,
#          'metropolis fremantle fremantle WA': 1,
#          'milanos brighton beach brighton VIC': 1,
#          'mildura - field days site-benetook avenue mildura VIC': 1,
#          'mindil beach darwin NT': 1,
#          'miss libertine melbourne VIC': 1,
#          'mitchell creek upper kandanga QLD': 1,
#          'mobile business they come to you brisbane QLD': 1,
#          'mobile business they come to you melbourne VIC': 1,
#          'mobile business they come to you sydney NSW': 1,
#          'moda events portside hamilton QLD': 1,
#          'molong recreation ground molong NSW': 1,
#          'moorabbin indoor tennis centre moorabbin VIC': 1,
#          'morris hall churchie east brisbane QLD': 1,
#          'mount annan botanic garden mount annan NSW': 1,
#          'mount carrington carrington NSW': 1,
#          'mount isa civic centre mount isa QLD': 1,
#          'mount panorama bathurst bathurst,mount panorama NSW': 1,
#          'mount white glenworth valley NSW': 1,
#          'mulgowie hall and cricket grounds mulgowie QLD': 1,
#          'mulubinba room newcastle NSW': 1,
#          'mutdapilly mutdapilly QLD': 1,
#          'myer mural hall melbourne VIC': 1,
#          'mystique fortitude valley QLD': 1,
#          'nambucca cinema nambucca heads NSW': 1,
#          'nancy fairfax foyer kensington NSW': 1,
#          'nashdale hall orange NSW': 1,
#          'national anzac centre - albany albany WA': 1,
#          'national archives of australia parkes ACT': 1,
#          'national film and sound archive acton ACT': 1,
#          'national wine centre of australia hackney SA': 1,
#          'neill and trisha fords “alsace” polo fields veresdale scrub QLD': 1,
#          'nerang bicentennial hall southport QLD': 1,
#          'nerang pcyc nerang QLD': 1,
#          'netball central sydney NSW': 1,
#          'nevermind sydney NSW': 1,
#          'new guernica melbourne VIC': 1,
#          'newcastle conservatorium of music newcastle NSW': 1,
#          'newcastle entertainment centre broadmeadow NSW': 1,
#          'newcastle entertainment centre newcastle NSW': 1,
#          'newcastle room newcastle NSW': 1,
#          'newcastle sports ground newcastle NSW': 1,
#          'newman chapel parkville VIC': 1,
#          'nex wests newcastle newcastle west NSW': 1,
#          'ngilgi cave yallingup WA': 1,
#          'nida theatres atrium kensington NSW': 1,
#          'no 1 sports ground - newcastle nsw newcastle west NSW': 1,
#          'no 2 sportsground - newcastle newcastle NSW': 1,
#          'noah’s on the beach newcastle NSW': 1,
#          'nobbys lighthouse newcastle NSW': 1,
#          'noosa blue noosa heads QLD': 1,
#          'noosa christian outreach centre noosaville QLD': 1,
#          'norfolk basement fremantle WA': 1,
#          'north gardens ballarat wendouree VIC': 1,
#          'northcott building surry hills NSW': 1,
#          'northside conference centre crows nest NSW': 1,
#          'norwood concert hall norwood SA': 1,
#          'notes in newtown newtown NSW': 1,
#          'novotel perth langley perth WA': 1,
#          'nowingi place mildura mildura VIC': 1,
#          'nth coast botanic gardens coffs harbour coffs harbour NSW': 1,
#          'oak barrel sydney NSW': 1,
#          'oatlands house oatlands NSW': 1,
#          'off comedy cellar ultimo NSW': 1,
#          'off road rush beverley WA': 1,
#          'old chapel newington college stanmore stanmore NSW': 1,
#          'old errowanbang woolshed errowanbang NSW': 1,
#          'old magistrates court melbourne VIC': 1,
#          'old manly boatshed manly NSW': 1,
#          'old melbourne gaol melbourne VIC': 1,
#          'one city road southbank VIC': 1,
#          'orana cinema albany WA': 1,
#          'orange botanic gardens orange NSW': 1,
#          'orange function centre orange NSW': 1,
#          'orange north court orange NSW': 1,
#          'orbost secondary college arnold VIC': 1,
#          'oriental dance studio prairiewood NSW': 1,
#          'ornamental gardens mildura mildura VIC': 1,
#          'our lady of victories camberwell VIC': 1,
#          'out of the pan littlehampton SA': 1,
#          'outside side bar/wake up youth hostel sydney NSW': 1,
#          'overseas passenger terminal the rocks NSW': 1,
#          'oxford arts factory darlinghurst NSW': 1,
#          'pacific pines tavern gaven QLD': 1,
#          'pacific sun friends venue donnybrook QLD': 1,
#          'paddington woollahra galleries sydney NSW': 1,
#          'paddys beer deluxe albury NSW': 1,
#          'paintball city appin appin NSW': 1,
#          'paintball city monarto monarto SA': 1,
#          'paintball city muchea muchea WA': 1,
#          'paintball skirmish henley brook WA': 1,
#          'palacio grande richmond VIC': 1,
#          'palais 85 south perth WA': 1,
#          'palais hepburn springs hepburn springs VIC': 1,
#          'palais royale newcastle NSW': 1,
#          'palladium at crown melbourne VIC': 1,
#          'palm meadows golf course carrara QLD': 1,
#          'palmwoods memorial hall palmwoods QLD': 1,
#          'pampered hens workshop petersham NSW': 1,
#          'panthers bathurst sydney NSW': 1,
#          'panthers port macquarie port macquarie NSW': 1,
#          'paradise jet boating main beach QLD': 1,
#          'parkroyal - darling harbour sydney NSW': 1,
#          'parkwood tavern parkwood QLD': 1,
#          'parliament house canberra ACT': 1,
#          'parramatta pcyc parramatta NSW': 1,
#          'patrick cellar door coonawarra SA': 1,
#          'pelican beach main beach QLD': 1,
#          'peninsula central pier docklands VIC': 1,
#          'peninsula docklands VIC': 1,
#          'penrith [club paceway] penrith NSW': 1,
#          'penrith panthers penrith NSW': 1,
#          'performing arts newcastle newcastle NSW': 1,
#          'perimoor littlehampton SA': 1,
#          'perth concert hall perth WA': 1,
#          'perth stretch hummer perth WA': 1,
#          'perth writers festival precinct crawley WA': 1,
#          'peter forsyth auditorium glebe NSW': 1,
#          'piazza surfers paradise surfers paradise QLD': 1,
#          'picture this ballooning melbourne VIC': 1,
#          'pier live frankston frankston VIC': 1,
#          'players international gladstone QLD': 1,
#          "poet's corner wines mudgee NSW": 1,
#          'poolside at crown metropol perth burswood WA': 1,
#          'porsche centre sydney south alexandria NSW': 1,
#          'port douglas community hall port douglas QLD': 1,
#          'portico ballarat ballarat VIC': 1,
#          'power house toowoomba QLD': 1,
#          'prancing pony brewery crescent SA': 1,
#          'press book house newcastle NSW': 1,
#          'prince henry garden adelaide SA': 1,
#          'prince of wales bandroom st kilda VIC': 1,
#          'prince of wales bunbury WA': 1,
#          'prince of wales showgrounds bendigo bendigo VIC': 1,
#          'princes warf no 1 hobart TAS': 1,
#          'proserpine entertainment centre proserpine QLD': 1,
#          'public office west melbourne VIC': 1,
#          'published arthouse adelaide SA': 1,
#          'pyrenees ranges - victoria lexton VIC': 1,
#          'q deck surfers paradise QLD': 1,
#          'qld tennis centre tennyson QLD': 1,
#          'qt canberra canberra ACT': 1,
#          'quarry amphitheatre city beach WA': 1,
#          'quarry ampitheatre city beach WA': 1,
#          'queanbeyan conference centre queanbeyan NSW': 1,
#          'queanbeyan drive-in movies glebe NSW': 1,
#          'queen victoria building sydney  NSW': 1,
#          'queen victoria building sydney SYDNEY': 1,
#          'queenscliff music festival hesse VIC': 1,
#          'queenscliff music queenscliff VIC': 1,
#          'queensland raceway willowbank QLD': 1,
#          'queensland sport and athletics centre nathan QLD': 1,
#          'queensland state equestrian centre caboolture QLD': 1,
#          'questacon parkes ACT': 1,
#          'quicksilver group douglas,port douglas QLD': 1,
#          'quindalup boat ramp geographe WA': 1,
#          'raaf amberley ipswich QLD': 1,
#          'raaf base edinburgh edinburgh SA': 1,
#          'raceview tavern raceview QLD': 1,
#          'raging thunder portsmith QLD': 1,
#          'rally drive experience bacchus marsh VIC': 1,
#          'rally driving course bakers hill WA': 1,
#          'rally of canberra locations mount panorama NSW': 1,
#          'randwick ritz st pauls NSW': 1,
#          'rare records st kilda VIC': 1,
#          'real fun canberra ACT': 1,
#          'red gum function centre wentworthville NSW': 1,
#          'red hill auditorium perth red hill WA': 1,
#          'redcliffe cultural centre redcliffe QLD': 1,
#          'redcliffe jetty redcliffe QLD': 1,
#          'redemptorist monastery north perth WA': 1,
#          'redgate beach redgate,margaret river WA': 1,
#          'reef magic cruises cairns QLD': 1,
#          'regal ballroom northcote northcote VIC': 1,
#          'regal chorus room subiaco WA': 1,
#          'regal round room subiaco WA': 1,
#          'revolt melbourne kensington VIC': 1,
#          'revolver upstairs prahran VIC': 1,
#          'rhythmbeat cruises sydney harbour balmain NSW': 1,
#          'river room crown towers southbank VIC': 1,
#          'riverside reception brisbane QLD': 1,
#          'riverstage – mildura mildura VIC': 1,
#          'rmit storey hall melbourne melbourne VIC': 1,
#          'rna showgrounds bowen hills QLD': 1,
#          'rna showgrounds brisbane bowen,bowen hills QLD': 1,
#          'roachford wines coldstream VIC': 1,
#          'robert oatley vineyards mudgee NSW': 1,
#          'rock solid adventure unley SA': 1,
#          'rockhampton music bowl yaamba QLD': 1,
#          'rockhampton showgrounds wandal QLD': 1,
#          'rockhampton – cricket grounds qld rockhampton QLD': 1,
#          'romeo tent crawley WA': 1,
#          'rooftop crown melbourne melbourne VIC': 1,
#          'room 680 hawthorn VIC': 1,
#          'roseville cinema roseville NSW': 1,
#          "rosie o'grady's northbridge northbridge WA": 1,
#          'route 69 party bus sydney NSW': 1,
#          'royal australian mint deakin ACT': 1,
#          'royal botanic gardens melbourne south yarra VIC': 1,
#          'royal exhibition building nicholson VIC': 1,
#          'royal melbourne showgrounds ascot vale VIC': 2,
#          'royal precinct newcastle NSW': 1,
#          'royal randwick alison NSW': 1,
#          "ruby's lounge belgrave VIC": 1,
#          "ruby's lounge belgrave burwood VIC": 1,
#          'rumours international toowoomba QLD': 1,
#          'runaway bay tavern runaway bay QLD': 1,
#          'ryde civic centre ryde NSW': 1,
#          'ryhope toronto NSW': 1,
#          'sale - sale showgrounds sale VIC': 1,
#          'sale memorial hall sale VIC': 1,
#          'salt on the beach north fremantle WA': 1,
#          'sanctuary cove sanctuary cove QLD': 1,
#          'sandalford wines margaret river wilyabrup WA': 1,
#          'sandalford wines swan valley west swan WA': 1,
#          'sandi warren performing arts centre cooks hill NSW': 1,
#          'sandown international raceway melbourne VIC': 1,
#          'sandown raceway springvale VIC': 1,
#          "santorini mykononos - watson's bay sydney NSW": 1,
#          'saumarez homestead armidale armidale NSW': 1,
#          'sawtell first avenue cinema sawtell NSW': 1,
#          'sazon espresso gawler SA': 1,
#          'scitech west perth WA': 1,
#          'sea world main beach QLD': 1,
#          'secret venue - margaret river margaret river WA': 1,
#          'secret venue - sydney sydney NSW': 1,
#          'sellicks beach adelaide,sellicks beach SA': 1,
#          'semoz paintballing moama deniliquin NSW': 1,
#          'seppelt wines great western VIC': 1,
#          'settlers tavern margaret river WA': 1,
#          'seven niteclub hervey bay QLD': 1,
#          'seymour centre chippendale NSW': 1,
#          'shark dive extreme manly NSW': 1,
#          'shed 9 central pier docklands VIC': 1,
#          'shepparton showgrounds shepparton VIC': 1,
#          "shepparton st mel's hall shepparton VIC": 1,
#          'shipwreck bay holiday warrnambool VIC': 1,
#          'shoalhaven entertainment centre nowra NSW': 1,
#          'sidney myer music bowl melbourne VIC': 1,
#          'silk road melbourne VIC': 1,
#          'silverdome prospect TAS': 1,
#          'singleton civic centre singleton NSW': 1,
#          'sirc penrith jetpack lake castlereagh NSW': 1,
#          'sketch docklands docklands VIC': 1,
#          'skydive cairns cairns QLD': 1,
#          'skydive nagambie nagambie VIC': 1,
#          'skydive queensland oxenford QLD': 1,
#          'skydive ramblers toogoolawah drop zone brisbane QLD': 1,
#          'skypoint observation deck surfers paradise QLD': 1,
#          'skyrail rainforest cableway smithfield QLD': 1,
#          'skywalk at the sydney tower eye sydney NSW': 1,
#          'slide lounge cabaret events darlinghurst NSW': 1,
#          'smithton recreation ground smithton TAS': 1,
#          'smitten with style coogee NSW': 1,
#          'sofitel brisbane brisbane QLD': 1,
#          'sofitel melbourne  VIC': 1,
#          'sofitel melbourne MELBOURNE': 1,
#          'somerled cellar door hahndorf SA': 1,
#          'sound lounge seymour centre chippendale NSW': 1,
#          'south morang plenty ranges arts centre south morang VIC': 1,
#          'south west adventures portland portland VIC': 1,
#          'southport sharks southport QLD': 1,
#          'space liverpool NSW': 1,
#          'spice kitchen kensington SA': 1,
#          'spiegeltent sydney sydney NSW': 1,
#          'spiegelworld batman VIC': 1,
#          'sports centre brisbane entertainment centre boondall QLD': 1,
#          'sportsworld entertainment centre nelson NSW': 1,
#          'springfield tavern springfield QLD': 1,
#          'springwood civic centre springwood NSW': 1,
#          'sra ground condobolin condobolin NSW': 1,
#          'st francis de sales college mount barker SA': 1,
#          "st john's southgate southbank VIC": 1,
#          "st joseph's college spring hill QLD": 1,
#          'st kilda - adjacent st kilda sea baths st kilda VIC': 1,
#          'st mary star of the sea melbourne,west melbourne VIC': 1,
#          'st patricks college ballarat ballarat VIC': 1,
#          'st pauls adelaide SA': 1,
#          'st stanislaus college bathurst NSW': 1,
#          'stanthorpe civic centre stanthorpe QLD': 1,
#          'star city grand harbour ballroom pyrmont NSW': 1,
#          'star city showroom pyrmont NSW': 1,
#          'state cinema north hobart TAS': 1,
#          'statement lounge sydney NSW': 1,
#          'stockton centre concert hall stockton NSW': 1,
#          'studio subiaco arts centre subiaco WA': 1,
#          'subiaco arts centre subiaco WA': 2,
#          'sugarland tavern bundaberg QLD': 1,
#          'sunbury memorial hall macedon VIC': 1,
#          'sunferries/sunsea cruises townsville QLD': 1,
#          'sunken garden crawley WA': 1,
#          'sunset safaris upper coomera QLD': 1,
#          'supercars circuit surfers paradise QLD': 1,
#          'supergp surfers paradise QLD': 1,
#          'supreme court gardens perth WA': 1,
#          'surfers paradise pass coomera QLD': 1,
#          'surfworld leisure centre torquay VIC': 1,
#          'sutherland entertainment centre sutherland NSW': 1,
#          'swan basement north fremantle WA': 1,
#          "sweeny's scenic hills campbelltown NSW": 1,
#          'sydney conservatorium of music sydney NSW': 1,
#          'sydney entertainment centre  NSW': 1,
#          'sydney entertainment centre SYDNEY': 1,
#          'sydney five in one sydney NSW': 1,
#          'sydney habour tall ship adventure sail the rocks NSW': 1,
#          'sydney harbour sydney NSW': 1,
#          'sydney helitours mascot NSW': 1,
#          'sydney international regatta centre castlereagh NSW': 1,
#          'sydney tower 4d cinema experience sydney NSW': 1,
#          'sydney whale watching sydney NSW': 1,
#          'symmons plains raceway perth TAS': 1,
#          'tailem bend tailem bend SA': 1,
#          'tamworth - australian equine and livestock events centre aelec goonoo goonoo NSW': 1,
#          'tamworth regional entertainment centre tamworth NSW': 1,
#          'tapis rouge suite - adelaide entertainment centre hindmarsh SA': 1,
#          'tapis rouge suite - brisbane ent centre boondall QLD': 1,
#          'tapis rouge suite – newcastle entertainment centre broadmeadow NSW': 1,
#          'tasmania five in one hobart TAS': 1,
#          'tasmania launceston,longford TAS': 1,
#          'tasmanian equestrian centre lauderdale TAS': 1,
#          'tasmanian hockey centre hobart TAS': 1,
#          'taylors arm taylors arm NSW': 1,
#          'tca ground hobart queens domain TAS': 1,
#          'telstra dome melbourne docklands VIC': 1,
#          'tennant creek - showgrounds tennant creek NT': 1,
#          'the amphitheatre darwin darwin NT': 1,
#          'the arisaig tea rooms surry hills NSW': 1,
#          'the arkaba glen osmond SA': 1,
#          'the arts centre gold coast surfers paradise QLD': 1,
#          'the arts centre hamer hall st kilda VIC': 1,
#          'the assembly hall melbourne VIC': 1,
#          'the auditorium erindale vikings wanniassa ACT': 1,
#          'the avalon on the beach avalon beach NSW': 1,
#          'the ballroom canberra ACT': 1,
#          'the basement belconnen ACT': 1,
#          'the basement sydney NSW': 1,
#          'the bourbon kings cross NSW': 1,
#          'the briars historical homestead mount martha VIC': 1,
#          'the brookfield showgrounds brookfield QLD': 1,
#          'the capital bendigo bendigo VIC': 2,
#          'the cellars melbourne VIC': 1,
#          'the civic pavilion chatswood NSW': 1,
#          "the comic's lounge north melbourne VIC": 1,
#          'the concourse terrace chatswood NSW': 1,
#          'the cornish arms brunswick VIC': 1,
#          'the cube camden NSW': 1,
#          'the domain sydney NSW': 1,
#          'the dome at crown perth burswood WA': 1,
#          'the dome melbourne VIC': 1,
#          'the edwards newcastle NSW': 1,
#          'the entrance the entrance NSW': 1,
#          'the esplanade perth WA': 1,
#          'the establishment ballroom sydney NSW': 1,
#          'the events centre caloundra caloundra QLD': 1,
#          'the fort fortitude valley QLD': 1,
#          'the gabba - brisbane cricket ground brisbane QLD': 1,
#          'the george wood ringwood ringwood VIC': 1,
#          'the gov hindmarsh SA': 1,
#          'the grand boulevard tavern joondalup,perth WA': 1,
#          'the green room canberra ACT': 1,
#          'the haus hahndorf SA': 1,
#          'the hi-fi brisbane west end QLD': 1,
#          'the hi-fi melbourne melbourne VIC': 1,
#          'the hills centre castle hill NSW': 1,
#          'the international of brighton brighton VIC': 1,
#          'the juniors kingsford NSW': 1,
#          'the juniors kingsford kingsford NSW': 1,
#          'the mean fiddler rouse hill NSW': 1,
#          'the melbourne athenaeum melbourne VIC': 1,
#          'the met - brisbane fortitude valley QLD': 1,
#          'the old mill hahndorf hahndorf SA': 1,
#          'the oxford bathurst NSW': 1,
#          'the palace complex st kilda VIC': 1,
#          'the palace coogee NSW': 1,
#          'the passage darlinghurst NSW': 1,
#          'the peninsula lounge moorooduc VIC': 1,
#          'the promethean adelaide SA': 1,
#          'the pub bendigo VIC': 1,
#          'the rev fortitude valley QLD': 1,
#          'the river room at crown melbourne VIC': 1,
#          'the royal botanic garden sydney sydney NSW': 1,
#          'the royal brisbane showgrounds bowen hills QLD': 1,
#          'the rydges backlot melbourne VIC': 1,
#          'the shores function complex west beach SA': 2,
#          'the showroom sandy bay TAS': 1,
#          'the standard bourke NSW': 1,
#          'the star event centre pyrmont NSW': 1,
#          'the star pyrmont NSW': 1,
#          'the three brothers arms macclesfield SA': 1,
#          'the tivoli fortitude valley QLD': 1,
#          'the toff in town melbourne VIC': 1,
#          'the triffid newstead QLD': 1,
#          'the troccadero surfers paradise QLD': 1,
#          'the tuxedo cat melbourne VIC': 1,
#          'the vanguard newtown NSW': 2,
#          'the warehouse devonport devonport TAS': 1,
#          'the west end at crown clarendon VIC': 1,
#          'the westin sydney sydney NSW': 1,
#          'the white house hahndorf hahndorf SA': 1,
#          'the wick melbourne VIC': 1,
#          'thompsons beach cobram VIC': 1,
#          'ticketek docklands VIC': 1,
#          'tom flood sports centre bendigo VIC': 1,
#          'tomaree education centre salamander bay NSW': 1,
#          'tomaree sports complex nelson bay NSW': 1,
#          "tomba's niteclub toowoomba QLD": 1,
#          'tondoon botanic gardens gladstone gladstone QLD': 1,
#          'toowoomba showgrounds glenvale QLD': 1,
#          'toowoomba sports ground toowoomba QLD': 1,
#          'top marque sports prestige hire fortitude valley QLD': 1,
#          'townsville - showgrounds qld townsville QLD': 1,
#          'townsville townsville QLD': 1,
#          'trades hall carlton VIC': 1,
#          'trak showroom toorak VIC': 1,
#          'treasury brisbane brisbane QLD': 1,
#          'troubadour fortitude valley QLD': 1,
#          'tuncurry memorial hall tuncurry NSW': 1,
#          'tweed heads - jack evans boat harbour tweed heads NSW': 1,
#          'two feet a heartbeat paddington NSW': 1,
#          'tyrrells vineyards at pokolbin pokolbin NSW': 1,
#          'udder delights hahndorf SA': 1,
#          'ulladulla civic centre ulladulla NSW': 1,
#          'valvoline raceway wentworth NSW': 1,
#          'vancouver arts centre albany WA': 1,
#          'varga lounge northbridge WA': 1,
#          'various locations canberra ACT': 1,
#          'various venues around goulburn goulburn NSW': 1,
#          'velvet lounge perth WA': 1,
#          'venue 505 surry hills NSW': 1,
#          'venue-3 melbourne VIC': 1,
#          'verbrugghen hall sydney NSW': 1,
#          'victoria festival of motion image melbourne VIC': 1,
#          'victoria hall fremantle WA': 1,
#          'victoria melbourne VIC': 1,
#          'victoria quay - fremantle harbour fremantle WA': 1,
#          'villa noosa noosaville QLD': 1,
#          'wagga wagga music bowl wagga wagga NSW': 1,
#          'wagga wagga showgrounds wagga wagga NSW': 1,
#          'wallsend diggers newcastle NSW': 1,
#          'wardrobe detox shop n learn sydney NSW': 1,
#          'warner bros movie world oxenford QLD': 1,
#          'warner village theme parks oxenford QLD': 1,
#          'warners bay performing arts centre warners bay NSW': 1,
#          'warrnambool showgrounds koroit VIC': 1,
#          'waterfront city docklands docklands VIC': 1,
#          'watermark melbourne melbourne VIC': 1,
#          'wayville showgrounds wayville SA': 1,
#          "welsh's road milbrodale milbrodale NSW": 1,
#          'wendouree performing arts centre wendouree VIC': 1,
#          'wendouree sports and events centre ballarat wendouree VIC': 1,
#          'wesley conference centre sydney NSW': 1,
#          'wesley music centre forrest ACT': 1,
#          'west cowra recreation ground cowra NSW': 1,
#          'west gippsland arts centre warragul VIC': 1,
#          'western australian cricket association east perth WA': 1,
#          'westgate sports leisure complex altona north VIC': 1,
#          'wests ashfield liverpool NSW': 1,
#          'wests city newcastle,newcastle west NSW': 1,
#          'wests leagues leumeah NSW': 1,
#          "wet'n'wild water world oxenford QLD": 1,
#          'whales in paradise surfers paradise QLD': 1,
#          'whitewater world coomera QLD': 1,
#          'whitlam leisure centre liverpool NSW': 1,
#          'wild ride australia sydney NSW': 1,
#          'wildfire sydney sydney NSW': 1,
#          'willoughby civic centre chatswood NSW': 1,
#          'willowbank raceway willowbank QLD': 1,
#          'wilson boathouse manly manly QLD': 1,
#          'wimmera events centre longerenong VIC': 1,
#          'win entertainment centre wollongong NSW': 1,
#          'windsor function centre windsor NSW': 1,
#          'winthrop hall uwa crawley WA': 1,
#          'winton motor raceway winton VIC': 1,
#          'wizard of oz funland leumeah NSW': 1,
#          'wollongong botanic gardens keiraville NSW': 1,
#          'wollongong uni function centre gwynneville NSW': 1,
#          'woodford showgrounds neurum QLD': 1,
#          'woodvale tavern woodvale WA': 1,
#          'world of whisky double bay NSW': 1,
#          'wrx experience jacobs well QLD': 1,
#          'wsid sydney dragway eastern creek NSW': 1,
#          'wyndham cultural centre werribee VIC': 1,
#          'xanadu wines - margaret river margaret river WA': 1,
#          'xup event site warnervale NSW': 1,
#          'yass showgrounds yass NSW': 1,
#          'yongala dive alva QLD': 1,
#          'yukis at the quay sydney NSW': 1})

# %% [markdown]
# Collect all venues suitable for giving to Google Maps in one data frame with a search line.

# %%
venues.drop(["city","state","suburb"], axis=1, inplace=True)

# %%
venues
# Out:
#            lat0        lng0                                       search_line  \
# 2    -28.035530  153.432890              1 two 3 mediterranean broadbeach QLD
# 4    -37.811907  144.968272                         170 russell melbourne VIC
# 14   -37.802170  145.003780                 abbotsford convent abbotsford VIC
# 15   -31.951680  115.873080                   abc perth studios east perth WA
# 17   -33.392609  149.518807                       abercrombie house ophir NSW
# 18   -33.613940  115.110719        aboard the kimberley quest ii quindalup WA
# 20   -35.279020  149.133250                              academy canberra ACT
# 21   -34.923210  138.606350                       academy cinema hindmarsh SA
# 22   -37.828871  144.941085    academy of design australia port melbourne VIC
# 23   -37.826700  144.966560                                acca melbourne VIC
# 28   -33.661080  150.923610      action paintball - rouse hill rouse hill NSW
# 29   -32.378840  115.921190       action paintball - serpentine serpentine WA
# 30   -37.817073  140.785448  activ8 health and sports centre mount gambier SA
# 31   -36.730200  146.960900       active flight paragliding bright bright VIC
# 32   -33.889410  151.203450      actt the old performance space cleveland NSW
# 34   -35.258880  138.890350                           adelaide strathalbyn SA
# 39   -34.909800  138.570810        adelaide entertainment centre hindmarsh SA
# 42   -34.916310  138.598940              adelaide festival centre adelaide SA
# 43   -34.916310  138.598940        adelaide festival centre trust adelaide SA
# 44   -34.944800  138.599290                   adelaide film festival unley SA
# 45   -34.922490  138.609330                       adelaide fringe ebenezer SA
# 53   -34.945860  138.586910                  adelaide showgrounds wayville SA
# 55   -34.792830  138.693640         adelaide tandem skydiving golden grove SA
# 58   -33.500140  150.809430  adventure quest paintball skirmish singleton NSW
# 59   -32.092690  115.820520                     adventure world bibra lake WA
# 67   -27.345940  152.966430              albany creek tavern albany creek QLD
# 68   -35.029380  117.886640             albany entertainment centre albany WA
# 71   -41.432900  147.141490                        albert hall launceston TAS
# 72   -35.284700  149.128110                          albert hall canberra ACT
# 78   -28.036930  153.424720               albert waterways mermaid waters QLD
# ...         ...         ...                                               ...
# 2887 -27.844465  153.305712                      whitewater world coomera QLD
# 2888 -33.923380  150.911890              whitlam leisure centre liverpool NSW
# 2894 -33.873650  151.206890                    wild ride australia sydney NSW
# 2895 -33.873650  151.206890                        wildfire sydney sydney NSW
# 2899 -33.796130  151.183090             willoughby civic centre chatswood NSW
# 2902 -27.692140  152.665370                 willowbank raceway willowbank QLD
# 2905 -27.451770  153.189520                  wilson boathouse manly manly QLD
# 2906 -36.671534  142.305715             wimmera events centre longerenong VIC
# 2907 -34.426220  150.902150           win entertainment centre wollongong NSW
# 2909 -33.610020  150.817910               windsor function centre windsor NSW
# 2912 -31.976629  115.818901                      winthrop hall uwa crawley WA
# 2913 -36.526640  146.096210                   winton motor raceway winton VIC
# 2915 -34.053220  150.824820                  wizard of oz funland leumeah NSW
# 2916 -34.407770  150.875830         wollongong botanic gardens keiraville NSW
# 2922 -34.408280  150.880380    wollongong uni function centre gwynneville NSW
# 2925 -26.950380  152.755990                   woodford showgrounds neurum QLD
# 2927 -31.783870  115.787000                       woodvale tavern woodvale WA
# 2929 -33.877130  151.242280                    world of whisky double bay NSW
# 2932 -27.812830  153.292810                    wrx experience jacobs well QLD
# 2934 -33.808740  150.866580             wsid sydney dragway eastern creek NSW
# 2935 -37.903720  144.657410              wyndham cultural centre werribee VIC
# 2940 -33.982600  115.056470   xanadu wines - margaret river margaret river WA
# 2941 -33.253860  151.440220                     xup event site warnervale NSW
# 2947 -34.842214  148.923009                         yass showgrounds yass NSW
# 2951 -20.917570  142.702800                             yongala dive alva QLD
# 2959 -33.858371  151.209548                      yukis at the quay sydney NSW
# 765  -38.145220  144.347553                           dromoland house GEELONG
# 1926 -31.253220  146.921100             queen victoria building sydney SYDNEY
# 2201 -37.671650  145.148900                       sofitel melbourne MELBOURNE
# 2365 -33.872340  151.198980                sydney entertainment centre SYDNEY
#
#                                                  v_addr     v_code  \
# 2                      shop  surf parade broadbeach qld        med
# 4                              russell st melbourne vic        rus
# 14                     st heliers street abbotsford vic        abs
# 15                             fielder st east perth wa        abp
# 17                                ophir rd bathurst nsw        aho
# 18               pro-fisherman's boat ramp quindalup wa        kqu
# 20                       bunda street canberra city act        acb
# 21                             hindmarsh sq adelaide sa        adc
# 22                     ingles street port melbourne vic        aod
# 23                 sturt street southbank melbourne vic  vaccamelb
# 28        - annangrove rd cnr edwards rd rouse hill nsw        rou
# 29                            punrak road serpentine wa        ser
# 30                         penola road mount gambier sa        amg
# 31                                           bright vic        afp
# 32                         cleveland street redfern nsw        spa
# 34                   goldrush ballooning strathalbyn sa        agr
# 39        corner port road and adam street hindmarsh sa        aec
# 42                          king william rd adelaide sa        afc
# 43                          king william rd adelaide sa      x-afc
# 44                             king william rd unley sa      x-aff
# 45    1st floor ebenezer place corner rundle street ...      x-adf
# 53                                 wayville pavilion sa        way
# 55                              po box  golden grove sa        ats
# 58                      singleton rd kurrajong east nsw        aqp
# 59                         progress drive bibra lake wa        awp
# 67                     albany creek rd albany creek qld        aln
# 68        toll place off princess royal drive albany wa        aew
# 71     corner of tamar cimitiere streets launceston tas        acl
# 72                        commonwealth ave canberra act        ahc
# 78                sunshine boulevard mermaid waters qld        abw
# ...                                                 ...        ...
# 2887                            pacific hwy coomera qld        whw
# 2888                      memorial avenue liverpool nsw        lam
# 2894                          sydney blue mountains nsw        wra
# 2895  ground level overseas passenger terminal sydne...        wfs
# 2899                      victoria avenue chatswood nsw        wcc
# 2902                       champions way willowbank qld        qrn
# 2905                             trafalgar st manly qld        wbh
# 2906                    field days road longerenong vic        wev
# 2907    corner harbour and crown streets wollongong nsw        wec
# 2909                           macquarie st windsor nsw        wfu
# 2912                            stirling hwy crawley wa        wph
# 2913                              fox street winton vic        wmr
# 2915                        / hollylea road leumeah nsw        wiz
# 2916                  northfields avenue keiraville nsw        wbg
# 2922                 northfields avenue gwynneville nsw      ~wuf~
# 2925                           neurum road woodford qld        wsg
# 2927                         trappers drive woodvale wa        wvt
# 2929              shp  /  knox st double bay sydney nsw        wow
# 2932          lot  pimpama jacobs well road pimpama qld        wrx
# 2934                       ferrers rd eastern creek nsw        wsd
# 2935                         watton street werribee vic        wye
# 2940      boodjidup road xanadu wines margaret river wa        xan
# 2941                     wattanobbi road warnervale nsw        xup
# 2947                       grand junction road yass nsw        boe
# 2951                       narrah street alva beach qld        yon
# 2959  level  overseas passenger terminal west circul...        yjp
# 765                        pakington st geelong west vc        drh
# 1926              the tea rooms level  northern end nsw      ~qvb~
# 2201                                     collins st vic        sfm
# 2365                     harbour st darling harbour nsw      x-sec
#
#                                   v_name
# 2                  1 two 3 mediterranean
# 4                            170 russell
# 14                    abbotsford convent
# 15                     abc perth studios
# 17                     abercrombie house
# 18         aboard the kimberley quest ii
# 20                               academy
# 21                        academy cinema
# 22           academy of design australia
# 23                                  acca
# 28         action paintball - rouse hill
# 29         action paintball - serpentine
# 30       activ8 health and sports centre
# 31      active flight paragliding bright
# 32        actt the old performance space
# 34                              adelaide
# 39         adelaide entertainment centre
# 42              adelaide festival centre
# 43        adelaide festival centre trust
# 44                adelaide film festival
# 45                       adelaide fringe
# 53                  adelaide showgrounds
# 55             adelaide tandem skydiving
# 58    adventure quest paintball skirmish
# 59                       adventure world
# 67                   albany creek tavern
# 68           albany entertainment centre
# 71                           albert hall
# 72                           albert hall
# 78                      albert waterways
# ...                                  ...
# 2887                    whitewater world
# 2888              whitlam leisure centre
# 2894                 wild ride australia
# 2895                     wildfire sydney
# 2899             willoughby civic centre
# 2902                  willowbank raceway
# 2905              wilson boathouse manly
# 2906               wimmera events centre
# 2907            win entertainment centre
# 2909             windsor function centre
# 2912                   winthrop hall uwa
# 2913                winton motor raceway
# 2915                wizard of oz funland
# 2916          wollongong botanic gardens
# 2922      wollongong uni function centre
# 2925                woodford showgrounds
# 2927                     woodvale tavern
# 2929                     world of whisky
# 2932                      wrx experience
# 2934                 wsid sydney dragway
# 2935             wyndham cultural centre
# 2940       xanadu wines - margaret river
# 2941                      xup event site
# 2947                    yass showgrounds
# 2951                        yongala dive
# 2959                   yukis at the quay
# 765                      dromoland house
# 1926      queen victoria building sydney
# 2201                   sofitel melbourne
# 2365         sydney entertainment centre
#
# [1007 rows x 6 columns]

# %%
gmaps = googlemaps.Client(key='AIzaSyCsJnOb6VESNe9C-BXpkbrLppPA2ygCJMg')

# %%
def find_coords(st):
    
    attempted_search_res = gmaps.geocode(st)
    
    if attempted_search_res:
        res = (attempted_search_res[0]["geometry"]["location"], attempted_search_res[0]['formatted_address'])
        return res  
    else:   
        return ({'lat': None, 'lng': None}, None)  

venues["result"] = None
venues.ix[:,"result"] = venues.ix[:,"search_line"].apply(find_coords)

# %%
venues["lng"] = venues.loc[:,"result"].apply(lambda x: x[0]['lng'])
venues["lat"] = venues.loc[:,"result"].apply(lambda x: x[0]['lat'])
venues["adr"] = venues.loc[:,"result"].apply(lambda x: x[1])

# %%
res0 = venues.loc[:,["v_code","v_name","v_addr","lat0","lat", "lng0", "lng","adr"]]

# %%
res0.head()
# Out:
#    v_code                 v_name                             v_addr  \
# 2     med  1 two 3 mediterranean   shop  surf parade broadbeach qld
# 4     rus            170 russell           russell st melbourne vic
# 14    abs     abbotsford convent   st heliers street abbotsford vic
# 15    abp      abc perth studios           fielder st east perth wa
# 17    aho      abercrombie house              ophir rd bathurst nsw
#
#          lat0        lat        lng0         lng  \
# 2  -28.035530 -28.028273  153.432890  153.430982
# 4  -37.811907 -37.812043  144.968272  144.968038
# 14 -37.802170 -37.802465  145.003780  145.002900
# 15 -31.951680 -31.951747  115.873080  115.873288
# 17 -33.392609 -33.392716  149.518807  149.518933
#
#                                                   adr flagged
# 2   Shop 10 & 11 Phoenician Tower East Surf Pde, B...   False
# 4       170 Russell St, Melbourne VIC 3000, Australia   False
# 14    1 St Heliers St, Abbotsford VIC 3067, Australia   False
# 15       30 Fielder St, East Perth WA 6004, Australia   False
# 17         311 Ophir Rd, Bathurst NSW 2795, Australia   False

# %%
res0["flagged"] = (abs(res0["lat0"] - res0["lat"]) >= 0.1) |  (abs(res0["lng0"] - res0["lng"]) >= 0.1)

# %%
rr1 = res0[res0.flagged == False]

# %%
len(rr)
# Out:
# 54

# %%
rr.drop("flagged",inplace=True,axis=1)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
rr.to_csv("venues_to_investigate.csv",index=False, sep="\t")

# %%
v_bad.to_csv("bad_venues.csv",index=False, sep="\t")

# %%
v_bad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 248 entries, 2964 to 2952
# Data columns (total 5 columns):
# v_code    248 non-null object
# v_name    185 non-null object
# v_addr    185 non-null object
# lat0      219 non-null float64
# lng0      219 non-null float64
# dtypes: float64(2), object(3)
# memory usage: 11.6+ KB

# %%
rr1.to_csv("venues_by_gmaps.csv",index=False, sep="\t")
